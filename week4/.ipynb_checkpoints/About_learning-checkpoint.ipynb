# %%
import numpy as np
import matplotlib as plt

# %% [markdown]
# ## Optimizer Compare

# %%
class SGD:
    def __init__(self, lr=0.01):
        self.lr = lr
    def update(self, params, grads):
        for key in params.keys():
            params[key] -= lr*grads[key]

# %%
class Momentum:
    def __init__(self, lr=0.01, momemtum=0.9):
        self.lr= lr
        self.momemtum= momentum
        self.v = None
    def update(self, params, grads):
        if(self.v is None):
            self.v = {}
            for key, value in params.items():
                self.v[key] = np.zeros_like(val)
        for key in params.keys():
            self.v[key] = self.momentum * self.v[key] - self.lr * grads[key]
            params[key] += self.v[key]

# %%
class AdaGrad:
    def __init__(self, lr=0.01):
        self.lr = lr
        self.h = None
    def update(self, params, grads):
        if self.h is None:
            self.h = {}
            for key, val in params.items():
                self.h[key] = np.zeros_like(val)
        for key in params.keys():
            self.h[key] += grads[key] * grads[key]
            params[key] -= self.lr * grads[key] / (np.sqrt(self.h[key]) + 1e-7)

# %%
grad = np.array([[1,2,3],[4,5,6]])
h = grad * grad
print(h)
# Out:
# [[ 1  4  9]
#  [16 25 36]]

# %% [markdown]
# ## Optimizer compare with mnist

# %%
# coding: utf-8
import os
import sys
sys.path.append("../DLFS_book/")  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.util import smooth_curve
from common.multi_layer_net import MultiLayerNet
from common.optimizer import *


# 0. MNIST 데이터 읽기==========
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

train_size = x_train.shape[0]
batch_size = 128
max_iterations = 2000


# 1. 실험용 설정==========
optimizers = {}
optimizers['SGD'] = SGD()
optimizers['Momentum'] = Momentum()
optimizers['AdaGrad'] = AdaGrad()
optimizers['Adam'] = Adam()
#optimizers['RMSprop'] = RMSprop()

networks = {}
train_loss = {}
for key in optimizers.keys():
    networks[key] = MultiLayerNet(
        input_size=784, hidden_size_list=[100, 100, 100, 100],
        output_size=10)
    train_loss[key] = []    


# 2. 훈련 시작==========
for i in range(max_iterations):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    for key in optimizers.keys():
        grads = networks[key].gradient(x_batch, t_batch)
        optimizers[key].update(networks[key].params, grads)
    
        loss = networks[key].loss(x_batch, t_batch)
        train_loss[key].append(loss)
    
    if i % 100 == 0:
        print( "===========" + "iteration:" + str(i) + "===========")
        for key in optimizers.keys():
            loss = networks[key].loss(x_batch, t_batch)
            print(key + ":" + str(loss))


# 3. 그래프 그리기==========
markers = {"SGD": "o", "Momentum": "x", "AdaGrad": "s", "Adam": "D"}
x = np.arange(max_iterations)
for key in optimizers.keys():
    plt.plot(x, smooth_curve(train_loss[key]), marker=markers[key], markevery=100, label=key)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.ylim(0, 1)
plt.legend()
plt.show()
# Out:
# ===========iteration:0===========
# SGD:2.3840182087500086
# Momentum:2.275966147614543
# AdaGrad:2.195675055218153
# Adam:2.177467842793539
# ===========iteration:100===========
# SGD:1.4826787016263447
# Momentum:0.3660007702658852
# AdaGrad:0.18217056919532476
# Adam:0.31062528193775296
# ===========iteration:200===========
# SGD:0.6428177230110267
# Momentum:0.17656081985143648
# AdaGrad:0.09175048014075757
# Adam:0.16988458404948686
# ===========iteration:300===========
# SGD:0.5042458900233748
# Momentum:0.17939920493500228
# AdaGrad:0.065786735068709
# Adam:0.09397756677714802
# ===========iteration:400===========
# SGD:0.3858043241860679
# Momentum:0.21529106798983064
# AdaGrad:0.09243887770165499
# Adam:0.13882901377181608
# ===========iteration:500===========
# SGD:0.35130320808613097
# Momentum:0.15454633933171172
# AdaGrad:0.08837801484745969
# Adam:0.15150895532666014
# ===========iteration:600===========
# SGD:0.2954872670370601
# Momentum:0.13262672021582472
# AdaGrad:0.053985836108976594
# Adam:0.09696201269553556
# ===========iteration:700===========
# SGD:0.32802590485034655
# Momentum:0.10489748039693424
# AdaGrad:0.04415947155052843
# Adam:0.06299808910584888
# ===========iteration:800===========
# SGD:0.29224974049297753
# Momentum:0.13765258727049182
# AdaGrad:0.053217427963501575
# Adam:0.12525776502523292
# ===========iteration:900===========
# SGD:0.33884626112759536
# Momentum:0.1524001764736
# AdaGrad:0.08205006501132497
# Adam:0.055985313137500055
# ===========iteration:1000===========
# SGD:0.2112538482403491
# Momentum:0.1452992719795295
# AdaGrad:0.06895693752744694
# Adam:0.040130922063324054
# ===========iteration:1100===========
# SGD:0.2411457073327746
# Momentum:0.09791955785289524
# AdaGrad:0.019242978594364975
# Adam:0.044637781899703306
# ===========iteration:1200===========
# SGD:0.3010733080831645
# Momentum:0.10869145718474701
# AdaGrad:0.04527992097100245
# Adam:0.05021415712014411
# ===========iteration:1300===========
# SGD:0.3644746553562343
# Momentum:0.17676402679147152
# AdaGrad:0.07937788709256696
# Adam:0.12211948850605917
# ===========iteration:1400===========
# SGD:0.21506069351714074
# Momentum:0.06001966962588194
# AdaGrad:0.02967658127929325
# Adam:0.042544354853458526
# ===========iteration:1500===========
# SGD:0.20798678620593883
# Momentum:0.034153683378440755
# AdaGrad:0.019884404712521148
# Adam:0.020039317604281834
# ===========iteration:1600===========
# SGD:0.11561531726509154
# Momentum:0.024492124458557585
# AdaGrad:0.012415344897559017
# Adam:0.01536998479526748
# ===========iteration:1700===========
# SGD:0.13342471814096296
# Momentum:0.028613800214229605
# AdaGrad:0.0119896297514104
# Adam:0.015238560204693802
# ===========iteration:1800===========
# SGD:0.13421930913955696
# Momentum:0.02128196734475453
# AdaGrad:0.010527420496439895
# Adam:0.010565612852770589
# ===========iteration:1900===========
# SGD:0.2694405217256254
# Momentum:0.08329423288728358
# AdaGrad:0.02730892047706447
# Adam:0.06365327179372907

# %% [markdown]
# ## Initialization of Weights

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))
def ReLU(x):
    return np.maximum(0, x)
def tanh(x):
    return np.tanh(x)

# %%
x = np.random.randn(1000, 100)  
node_num = 100 
hidden_layer_size = 5  
activations = {}

# %%
for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1] #앞에 값 가져옴
        
    w = np.random.randn(node_num, node_num) * 1 #initialization of weights
    #w = np.random.randn(node_num, node_num) * 0.01
    #w = np.random.randn(node_num, node_num) * np.sqrt(1.0 / node_num)
    #w = np.random.randn(node_num, node_num) * np.sqrt(2.0 / node_num)
    
    a = np.dot(x, w)
    z = sigmoid(a)
    #z = ReLU(a)
    #z = tanh(a)
    activations[i] = z

# %%
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    if i != 0: 
        plt.yticks([], [])
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()

# %% [markdown]
# ## Mnist를 통한 가중치 초기값 비교.

# %%
import os
import sys

sys.path.append("../DLFS_book")  
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.util import smooth_curve
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

# %%
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

train_size = x_train.shape[0]
batch_size = 128
max_iterations = 2000


# 1. 실험용 설정==========
weight_init_types = {'std=0.01': 0.01, 'Xavier': 'sigmoid', 'He': 'relu'}
optimizer = SGD(lr=0.01)

networks = {}
train_loss = {}
for key, weight_type in weight_init_types.items():
    networks[key] = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100],
                                  output_size=10, weight_init_std=weight_type)
    train_loss[key] = []
    


# 2. 훈련 시작==========
for i in range(max_iterations):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    for key in weight_init_types.keys():
        grads = networks[key].gradient(x_batch, t_batch)
        optimizer.update(networks[key].params, grads)
    
        loss = networks[key].loss(x_batch, t_batch)
        train_loss[key].append(loss)
    
    if i % 100 == 0:
        print("===========" + "iteration:" + str(i) + "===========")
        for key in weight_init_types.keys():
            loss = networks[key].loss(x_batch, t_batch)
            print(key + ":" + str(loss))


# 3. 그래프 그리기==========
markers = {'std=0.01': 'o', 'Xavier': 's', 'He': 'D'}
x = np.arange(max_iterations)
for key in weight_init_types.keys():
    plt.plot(x, smooth_curve(train_loss[key]), marker=markers[key], markevery=100, label=key)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.ylim(0, 2.5)
plt.legend()
plt.show()
# Out:
# ===========iteration:0===========
# std=0.01:2.3024718240333426
# Xavier:2.29348546919457
# He:2.3743754204781737
# ===========iteration:100===========
# std=0.01:2.3022871720924885
# Xavier:2.2478288424312565
# He:1.497226029558299
# ===========iteration:200===========
# std=0.01:2.302163014275734
# Xavier:2.1587239239000056
# He:0.7561641535480735
# ===========iteration:300===========
# std=0.01:2.301094244144897
# Xavier:1.864809237067309
# He:0.5103724542613173
# ===========iteration:400===========
# std=0.01:2.3019690942201176
# Xavier:1.4292335462095362
# He:0.376445770631324
# ===========iteration:500===========
# std=0.01:2.3019769953552633
# Xavier:0.9438720067318431
# He:0.35941573677256866
# ===========iteration:600===========
# std=0.01:2.2998744471619457
# Xavier:0.7882953428366314
# He:0.3571260954792885
# ===========iteration:700===========
# std=0.01:2.3015797172133423
# Xavier:0.7179513008495421
# He:0.37570458608443513
# ===========iteration:800===========
# std=0.01:2.3001787229502133
# Xavier:0.4765973068275776
# He:0.23585585984438048
# ===========iteration:900===========
# std=0.01:2.3032449549262695
# Xavier:0.5687981867215415
# He:0.3000895063520601
# ===========iteration:1000===========
# std=0.01:2.2983977041664048
# Xavier:0.44033054327563803
# He:0.25808161607068686
# ===========iteration:1100===========
# std=0.01:2.298193333669267
# Xavier:0.455729423292042
# He:0.33048187470984286
# ===========iteration:1200===========
# std=0.01:2.3012026616058217
# Xavier:0.4623864838639671
# He:0.2885410617566692
# ===========iteration:1300===========
# std=0.01:2.3044473874888447
# Xavier:0.31263001260678
# He:0.22655991291666092
# ===========iteration:1400===========
# std=0.01:2.297273254498894
# Xavier:0.34004747302629945
# He:0.1958364525872599
# ===========iteration:1500===========
# std=0.01:2.308386498173242
# Xavier:0.3819318661546972
# He:0.24208250127355152
# ===========iteration:1600===========
# std=0.01:2.3006491997716028
# Xavier:0.2973074100535998
# He:0.173623138541031
# ===========iteration:1700===========
# std=0.01:2.3068661808282727
# Xavier:0.34804526940553165
# He:0.25125294658009034
# ===========iteration:1800===========
# std=0.01:2.2995886814882067
# Xavier:0.28104609997665253
# He:0.20185777069989747
# ===========iteration:1900===========
# std=0.01:2.3058809342482016
# Xavier:0.3036174206372241
# He:0.25781847731392493

# %% [markdown]
# ## Batch Normalization

# %%
import sys, os
sys.path.append("../DLFS_book/")  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net_extend import MultiLayerNetExtend
from common.optimizer import SGD, Adam

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 학습 데이터를 줄임
x_train = x_train[:1000]
t_train = t_train[:1000]

max_epochs = 20
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01


def __train(weight_init_std):
    bn_network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100], output_size=10, 
                                    weight_init_std=weight_init_std, use_batchnorm=True)
    network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100], output_size=10,
                                weight_init_std=weight_init_std)
    optimizer = SGD(lr=learning_rate)
    
    train_acc_list = []
    bn_train_acc_list = []
    
    iter_per_epoch = max(train_size / batch_size, 1)
    epoch_cnt = 0
    
    for i in range(1000000000):
        batch_mask = np.random.choice(train_size, batch_size)
        x_batch = x_train[batch_mask]
        t_batch = t_train[batch_mask]
    
        for _network in (bn_network, network):
            grads = _network.gradient(x_batch, t_batch)
            optimizer.update(_network.params, grads)
    
        if i % iter_per_epoch == 0:
            train_acc = network.accuracy(x_train, t_train)
            bn_train_acc = bn_network.accuracy(x_train, t_train)
            train_acc_list.append(train_acc)
            bn_train_acc_list.append(bn_train_acc)
    
            print("epoch:" + str(epoch_cnt) + " | " + str(train_acc) + " - " + str(bn_train_acc))
    
            epoch_cnt += 1
            if epoch_cnt >= max_epochs:
                break
                
    return train_acc_list, bn_train_acc_list


# 그래프 그리기==========
weight_scale_list = np.logspace(0, -4, num=16)
x = np.arange(max_epochs)

for i, w in enumerate(weight_scale_list):
    print( "============== " + str(i+1) + "/16" + " ==============")
    train_acc_list, bn_train_acc_list = __train(w)
    
    plt.subplot(4,4,i+1)
    plt.title("W:" + str(w))
    if i == 15:
        plt.plot(x, bn_train_acc_list, label='Batch Normalization', markevery=2)
        plt.plot(x, train_acc_list, linestyle = "--", label='Normal(without BatchNorm)', markevery=2)
    else:
        plt.plot(x, bn_train_acc_list, markevery=2)
        plt.plot(x, train_acc_list, linestyle="--", markevery=2)

    plt.ylim(0, 1.0)
    if i % 4:
        plt.yticks([])
    else:
        plt.ylabel("accuracy")
    if i < 12:
        plt.xticks([])
    else:
        plt.xlabel("epochs")
    plt.legend(loc='lower right')
    
plt.show()
# Out:
# ============== 1/16 ==============
# epoch:0 | 0.097 - 0.106
# epoch:1 | 0.105 - 0.079
# /home/dongho/DLFS1/week4/../DLFS_book/common/multi_layer_net_extend.py:104: RuntimeWarning: overflow encountered in square
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# /home/dongho/DLFS1/week4/../DLFS_book/common/multi_layer_net_extend.py:104: RuntimeWarning: invalid value encountered in double_scalars
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# epoch:2 | 0.105 - 0.11
# epoch:3 | 0.105 - 0.122
# epoch:4 | 0.105 - 0.138
# epoch:5 | 0.105 - 0.161
# epoch:6 | 0.105 - 0.188
# epoch:7 | 0.105 - 0.204
# epoch:8 | 0.105 - 0.228
# epoch:9 | 0.105 - 0.239
# epoch:10 | 0.105 - 0.259
# epoch:11 | 0.105 - 0.275
# epoch:12 | 0.116 - 0.302
# epoch:13 | 0.116 - 0.307
# epoch:14 | 0.116 - 0.327
# epoch:15 | 0.116 - 0.337
# epoch:16 | 0.116 - 0.357
# epoch:17 | 0.116 - 0.369
# epoch:18 | 0.116 - 0.385
# epoch:19 | 0.116 - 0.396
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /home/dongho/DLFS1/week4/../DLFS_book/common/multi_layer_net_extend.py:104: RuntimeWarning: overflow encountered in square
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# /home/dongho/DLFS1/week4/../DLFS_book/common/multi_layer_net_extend.py:104: RuntimeWarning: invalid value encountered in double_scalars
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# ============== 2/16 ==============
# epoch:0 | 0.093 - 0.112
# epoch:1 | 0.097 - 0.115
# epoch:2 | 0.097 - 0.136
# epoch:3 | 0.097 - 0.177
# epoch:4 | 0.097 - 0.206
# epoch:5 | 0.097 - 0.232
# epoch:6 | 0.097 - 0.261
# epoch:7 | 0.097 - 0.293
# epoch:8 | 0.097 - 0.321
# epoch:9 | 0.097 - 0.339
# epoch:10 | 0.097 - 0.367
# epoch:11 | 0.097 - 0.376
# epoch:12 | 0.097 - 0.407
# epoch:13 | 0.097 - 0.417
# epoch:14 | 0.097 - 0.447
# epoch:15 | 0.097 - 0.466
# epoch:16 | 0.097 - 0.489
# epoch:17 | 0.097 - 0.499
# epoch:18 | 0.097 - 0.505
# epoch:19 | 0.097 - 0.531
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ============== 3/16 ==============
# epoch:0 | 0.15 - 0.108
# epoch:1 | 0.513 - 0.107
# epoch:2 | 0.617 - 0.143
# epoch:3 | 0.708 - 0.196
# epoch:4 | 0.771 - 0.238
# epoch:5 | 0.813 - 0.299
# epoch:6 | 0.845 - 0.351
# epoch:7 | 0.873 - 0.393
# epoch:8 | 0.905 - 0.433
# epoch:9 | 0.922 - 0.471
# epoch:10 | 0.946 - 0.497
# epoch:11 | 0.956 - 0.527
# epoch:12 | 0.965 - 0.55
# epoch:13 | 0.976 - 0.571
# epoch:14 | 0.98 - 0.583
# epoch:15 | 0.984 - 0.601
# epoch:16 | 0.987 - 0.612
# epoch:17 | 0.989 - 0.624
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:18 | 0.99 - 0.634
# epoch:19 | 0.993 - 0.661
# ============== 4/16 ==============
# epoch:0 | 0.107 - 0.067
# epoch:1 | 0.216 - 0.122
# epoch:2 | 0.317 - 0.184
# epoch:3 | 0.417 - 0.237
# epoch:4 | 0.497 - 0.297
# epoch:5 | 0.566 - 0.347
# epoch:6 | 0.637 - 0.394
# epoch:7 | 0.662 - 0.436
# epoch:8 | 0.682 - 0.49
# epoch:9 | 0.716 - 0.529
# epoch:10 | 0.742 - 0.573
# epoch:11 | 0.758 - 0.602
# epoch:12 | 0.771 - 0.638
# epoch:13 | 0.801 - 0.658
# epoch:14 | 0.823 - 0.685
# epoch:15 | 0.837 - 0.701
# epoch:16 | 0.828 - 0.723
# epoch:17 | 0.839 - 0.741
# epoch:18 | 0.846 - 0.752
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:19 | 0.857 - 0.77
# ============== 5/16 ==============
# epoch:0 | 0.082 - 0.077
# epoch:1 | 0.084 - 0.132
# epoch:2 | 0.097 - 0.282
# epoch:3 | 0.108 - 0.402
# epoch:4 | 0.122 - 0.519
# epoch:5 | 0.145 - 0.601
# epoch:6 | 0.149 - 0.652
# epoch:7 | 0.18 - 0.707
# epoch:8 | 0.197 - 0.746
# epoch:9 | 0.208 - 0.779
# epoch:10 | 0.218 - 0.802
# epoch:11 | 0.237 - 0.821
# epoch:12 | 0.245 - 0.832
# epoch:13 | 0.252 - 0.854
# epoch:14 | 0.259 - 0.869
# epoch:15 | 0.271 - 0.883
# epoch:16 | 0.282 - 0.894
# epoch:17 | 0.279 - 0.903
# epoch:18 | 0.279 - 0.904
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:19 | 0.283 - 0.914
# ============== 6/16 ==============
# epoch:0 | 0.079 - 0.128
# epoch:1 | 0.117 - 0.24
# epoch:2 | 0.117 - 0.421
# epoch:3 | 0.117 - 0.546
# epoch:4 | 0.117 - 0.608
# epoch:5 | 0.117 - 0.676
# epoch:6 | 0.117 - 0.731
# epoch:7 | 0.117 - 0.786
# epoch:8 | 0.117 - 0.814
# epoch:9 | 0.117 - 0.836
# epoch:10 | 0.117 - 0.861
# epoch:11 | 0.117 - 0.872
# epoch:12 | 0.117 - 0.888
# epoch:13 | 0.117 - 0.904
# epoch:14 | 0.117 - 0.913
# epoch:15 | 0.117 - 0.921
# epoch:16 | 0.117 - 0.94
# epoch:17 | 0.117 - 0.947
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:18 | 0.117 - 0.951
# epoch:19 | 0.117 - 0.954
# ============== 7/16 ==============
# epoch:0 | 0.099 - 0.1
# epoch:1 | 0.117 - 0.344
# epoch:2 | 0.116 - 0.634
# epoch:3 | 0.116 - 0.743
# epoch:4 | 0.116 - 0.788
# epoch:5 | 0.116 - 0.823
# epoch:6 | 0.116 - 0.864
# epoch:7 | 0.116 - 0.877
# epoch:8 | 0.117 - 0.907
# epoch:9 | 0.116 - 0.916
# epoch:10 | 0.116 - 0.935
# epoch:11 | 0.116 - 0.941
# epoch:12 | 0.116 - 0.955
# epoch:13 | 0.117 - 0.964
# epoch:14 | 0.117 - 0.968
# epoch:15 | 0.117 - 0.979
# epoch:16 | 0.117 - 0.985
# epoch:17 | 0.117 - 0.991
# epoch:18 | 0.117 - 0.992
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:19 | 0.117 - 0.993
# ============== 8/16 ==============
# epoch:0 | 0.117 - 0.092
# epoch:1 | 0.117 - 0.221
# epoch:2 | 0.117 - 0.611
# epoch:3 | 0.117 - 0.764
# epoch:4 | 0.117 - 0.816
# epoch:5 | 0.116 - 0.874
# epoch:6 | 0.116 - 0.909
# epoch:7 | 0.116 - 0.934
# epoch:8 | 0.116 - 0.954
# epoch:9 | 0.116 - 0.973
# epoch:10 | 0.116 - 0.98
# epoch:11 | 0.116 - 0.986
# epoch:12 | 0.116 - 0.991
# epoch:13 | 0.116 - 0.996
# epoch:14 | 0.116 - 0.996
# epoch:15 | 0.116 - 0.995
# epoch:16 | 0.116 - 0.997
# epoch:17 | 0.116 - 0.998
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:18 | 0.116 - 0.998
# epoch:19 | 0.116 - 0.998
# ============== 9/16 ==============
# epoch:0 | 0.117 - 0.091
# epoch:1 | 0.117 - 0.495
# epoch:2 | 0.116 - 0.682
# epoch:3 | 0.116 - 0.747
# epoch:4 | 0.116 - 0.813
# epoch:5 | 0.116 - 0.911
# epoch:6 | 0.116 - 0.953
# epoch:7 | 0.116 - 0.972
# epoch:8 | 0.117 - 0.981
# epoch:9 | 0.117 - 0.983
# epoch:10 | 0.117 - 0.992
# epoch:11 | 0.117 - 0.992
# epoch:12 | 0.117 - 0.993
# epoch:13 | 0.117 - 0.995
# epoch:14 | 0.117 - 0.995
# epoch:15 | 0.117 - 0.996
# epoch:16 | 0.117 - 0.997
# epoch:17 | 0.117 - 0.999
# epoch:18 | 0.117 - 0.999
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:19 | 0.117 - 0.999
# ============== 10/16 ==============
# epoch:0 | 0.093 - 0.116
# epoch:1 | 0.117 - 0.551
# epoch:2 | 0.117 - 0.735
# epoch:3 | 0.117 - 0.816
# epoch:4 | 0.117 - 0.872
# epoch:5 | 0.117 - 0.88
# epoch:6 | 0.117 - 0.884
# epoch:7 | 0.117 - 0.966
# epoch:8 | 0.117 - 0.987
# epoch:9 | 0.117 - 0.965
# epoch:10 | 0.117 - 0.987
# epoch:11 | 0.117 - 0.993
# epoch:12 | 0.117 - 0.994
# epoch:13 | 0.117 - 0.996
# epoch:14 | 0.117 - 0.996
# epoch:15 | 0.117 - 0.998
# epoch:16 | 0.117 - 0.971
# epoch:17 | 0.117 - 0.99
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:18 | 0.117 - 0.997
# epoch:19 | 0.117 - 0.998
# ============== 11/16 ==============
# epoch:0 | 0.1 - 0.116
# epoch:1 | 0.116 - 0.622
# epoch:2 | 0.116 - 0.755
# epoch:3 | 0.116 - 0.716
# epoch:4 | 0.117 - 0.827
# epoch:5 | 0.117 - 0.854
# epoch:6 | 0.117 - 0.897
# epoch:7 | 0.117 - 0.937
# epoch:8 | 0.117 - 0.924
# epoch:9 | 0.117 - 0.968
# epoch:10 | 0.117 - 0.979
# epoch:11 | 0.117 - 0.787
# epoch:12 | 0.117 - 0.979
# epoch:13 | 0.117 - 0.991
# epoch:14 | 0.117 - 0.989
# epoch:15 | 0.117 - 0.992
# epoch:16 | 0.117 - 0.987
# epoch:17 | 0.117 - 0.986
# epoch:18 | 0.117 - 0.992
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:19 | 0.117 - 0.995
# ============== 12/16 ==============
# epoch:0 | 0.092 - 0.099
# epoch:1 | 0.117 - 0.45
# epoch:2 | 0.117 - 0.644
# epoch:3 | 0.117 - 0.71
# epoch:4 | 0.117 - 0.614
# epoch:5 | 0.117 - 0.705
# epoch:6 | 0.117 - 0.778
# epoch:7 | 0.117 - 0.79
# epoch:8 | 0.117 - 0.793
# epoch:9 | 0.117 - 0.795
# epoch:10 | 0.117 - 0.794
# epoch:11 | 0.117 - 0.88
# epoch:12 | 0.117 - 0.881
# epoch:13 | 0.117 - 0.881
# epoch:14 | 0.117 - 0.89
# epoch:15 | 0.117 - 0.893
# epoch:16 | 0.117 - 0.951
# epoch:17 | 0.117 - 0.868
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:18 | 0.117 - 0.982
# epoch:19 | 0.117 - 0.983
# ============== 13/16 ==============
# epoch:0 | 0.116 - 0.141
# epoch:1 | 0.117 - 0.472
# epoch:2 | 0.117 - 0.565
# epoch:3 | 0.117 - 0.629
# epoch:4 | 0.117 - 0.607
# epoch:5 | 0.117 - 0.614
# epoch:6 | 0.117 - 0.644
# epoch:7 | 0.117 - 0.672
# epoch:8 | 0.117 - 0.691
# epoch:9 | 0.117 - 0.683
# epoch:10 | 0.117 - 0.695
# epoch:11 | 0.117 - 0.7
# epoch:12 | 0.117 - 0.7
# epoch:13 | 0.117 - 0.698
# epoch:14 | 0.117 - 0.693
# epoch:15 | 0.117 - 0.698
# epoch:16 | 0.117 - 0.696
# epoch:17 | 0.117 - 0.69
# epoch:18 | 0.117 - 0.704
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:19 | 0.117 - 0.703
# ============== 14/16 ==============
# epoch:0 | 0.117 - 0.142
# epoch:1 | 0.094 - 0.338
# epoch:2 | 0.116 - 0.493
# epoch:3 | 0.117 - 0.416
# epoch:4 | 0.116 - 0.545
# epoch:5 | 0.116 - 0.536
# epoch:6 | 0.116 - 0.548
# epoch:7 | 0.116 - 0.58
# epoch:8 | 0.116 - 0.584
# epoch:9 | 0.116 - 0.592
# epoch:10 | 0.116 - 0.598
# epoch:11 | 0.116 - 0.602
# epoch:12 | 0.116 - 0.609
# epoch:13 | 0.116 - 0.609
# epoch:14 | 0.116 - 0.615
# epoch:15 | 0.116 - 0.609
# epoch:16 | 0.117 - 0.613
# epoch:17 | 0.117 - 0.635
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:18 | 0.117 - 0.649
# epoch:19 | 0.117 - 0.7
# ============== 15/16 ==============
# epoch:0 | 0.1 - 0.19
# epoch:1 | 0.117 - 0.279
# epoch:2 | 0.117 - 0.405
# epoch:3 | 0.117 - 0.392
# epoch:4 | 0.117 - 0.411
# epoch:5 | 0.117 - 0.418
# epoch:6 | 0.116 - 0.425
# epoch:7 | 0.116 - 0.416
# epoch:8 | 0.116 - 0.424
# epoch:9 | 0.116 - 0.427
# epoch:10 | 0.116 - 0.429
# epoch:11 | 0.116 - 0.515
# epoch:12 | 0.116 - 0.509
# epoch:13 | 0.116 - 0.516
# epoch:14 | 0.116 - 0.516
# epoch:15 | 0.116 - 0.507
# epoch:16 | 0.116 - 0.527
# epoch:17 | 0.116 - 0.524
# epoch:18 | 0.116 - 0.527
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:19 | 0.117 - 0.333
# ============== 16/16 ==============
# epoch:0 | 0.117 - 0.244
# epoch:1 | 0.117 - 0.298
# epoch:2 | 0.117 - 0.496
# epoch:3 | 0.116 - 0.488
# epoch:4 | 0.116 - 0.513
# epoch:5 | 0.116 - 0.528
# epoch:6 | 0.116 - 0.505
# epoch:7 | 0.116 - 0.532
# epoch:8 | 0.116 - 0.592
# epoch:9 | 0.116 - 0.584
# epoch:10 | 0.116 - 0.583
# epoch:11 | 0.117 - 0.591
# epoch:12 | 0.117 - 0.608
# epoch:13 | 0.116 - 0.612
# epoch:14 | 0.117 - 0.601
# epoch:15 | 0.116 - 0.618
# epoch:16 | 0.117 - 0.616
# epoch:17 | 0.117 - 0.598
# epoch:18 | 0.117 - 0.613
# epoch:19 | 0.117 - 0.621

# %% [markdown]
# ## Overfitting

# %%
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

x_train = x_train[:300]
t_train = t_train[:300]

# %%
network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10)
optimizer = SGD(lr=0.01)

# %%
max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

# %%
for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0: #check if one epoch has passed
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break
# Out:
# epoch:0, train acc:0.07333333333333333, test acc:0.0474
# epoch:1, train acc:0.08666666666666667, test acc:0.0581
# epoch:2, train acc:0.10666666666666667, test acc:0.0722
# epoch:3, train acc:0.14, test acc:0.0964
# epoch:4, train acc:0.15333333333333332, test acc:0.107
# epoch:5, train acc:0.17, test acc:0.1276
# epoch:6, train acc:0.19666666666666666, test acc:0.1406
# epoch:7, train acc:0.19666666666666666, test acc:0.151
# epoch:8, train acc:0.21333333333333335, test acc:0.1563
# epoch:9, train acc:0.22333333333333333, test acc:0.1683
# epoch:10, train acc:0.24, test acc:0.1787
# epoch:11, train acc:0.26, test acc:0.1858
# epoch:12, train acc:0.27, test acc:0.1916
# epoch:13, train acc:0.31333333333333335, test acc:0.2061
# epoch:14, train acc:0.3233333333333333, test acc:0.2181
# epoch:15, train acc:0.35, test acc:0.2205
# epoch:16, train acc:0.37333333333333335, test acc:0.2405
# epoch:17, train acc:0.37666666666666665, test acc:0.2428
# epoch:18, train acc:0.4, test acc:0.2569
# epoch:19, train acc:0.41, test acc:0.2637
# epoch:20, train acc:0.42333333333333334, test acc:0.2979
# epoch:21, train acc:0.43, test acc:0.2939
# epoch:22, train acc:0.43333333333333335, test acc:0.2966
# epoch:23, train acc:0.47, test acc:0.3242
# epoch:24, train acc:0.48333333333333334, test acc:0.3389
# epoch:25, train acc:0.5233333333333333, test acc:0.372
# epoch:26, train acc:0.5733333333333334, test acc:0.4017
# epoch:27, train acc:0.6233333333333333, test acc:0.4281
# epoch:28, train acc:0.65, test acc:0.4524
# epoch:29, train acc:0.6766666666666666, test acc:0.4724
# epoch:30, train acc:0.6933333333333334, test acc:0.4845
# epoch:31, train acc:0.7166666666666667, test acc:0.4925
# epoch:32, train acc:0.73, test acc:0.5112
# epoch:33, train acc:0.7566666666666667, test acc:0.5274
# epoch:34, train acc:0.7733333333333333, test acc:0.5459
# epoch:35, train acc:0.7833333333333333, test acc:0.563
# epoch:36, train acc:0.8, test acc:0.5731
# epoch:37, train acc:0.7966666666666666, test acc:0.5931
# epoch:38, train acc:0.7933333333333333, test acc:0.5887
# epoch:39, train acc:0.8, test acc:0.6042
# epoch:40, train acc:0.81, test acc:0.6141
# epoch:41, train acc:0.8133333333333334, test acc:0.6173
# epoch:42, train acc:0.81, test acc:0.621
# epoch:43, train acc:0.8166666666666667, test acc:0.6302
# epoch:44, train acc:0.8133333333333334, test acc:0.6401
# epoch:45, train acc:0.8166666666666667, test acc:0.6282
# epoch:46, train acc:0.8266666666666667, test acc:0.643
# epoch:47, train acc:0.83, test acc:0.647
# epoch:48, train acc:0.8333333333333334, test acc:0.6475
# epoch:49, train acc:0.85, test acc:0.6558
# epoch:50, train acc:0.8566666666666667, test acc:0.6582
# epoch:51, train acc:0.87, test acc:0.6713
# epoch:52, train acc:0.88, test acc:0.6731
# epoch:53, train acc:0.8866666666666667, test acc:0.6756
# epoch:54, train acc:0.88, test acc:0.6808
# epoch:55, train acc:0.9, test acc:0.6892
# epoch:56, train acc:0.9, test acc:0.6884
# epoch:57, train acc:0.8966666666666666, test acc:0.693
# epoch:58, train acc:0.91, test acc:0.6979
# epoch:59, train acc:0.8966666666666666, test acc:0.6937
# epoch:60, train acc:0.9, test acc:0.6982
# epoch:61, train acc:0.9133333333333333, test acc:0.7053
# epoch:62, train acc:0.9133333333333333, test acc:0.7086
# epoch:63, train acc:0.92, test acc:0.7068
# epoch:64, train acc:0.92, test acc:0.7053
# epoch:65, train acc:0.9233333333333333, test acc:0.7087
# epoch:66, train acc:0.9266666666666666, test acc:0.713
# epoch:67, train acc:0.93, test acc:0.7162
# epoch:68, train acc:0.9366666666666666, test acc:0.7182
# epoch:69, train acc:0.94, test acc:0.7194
# epoch:70, train acc:0.9366666666666666, test acc:0.7235
# epoch:71, train acc:0.94, test acc:0.724
# epoch:72, train acc:0.9466666666666667, test acc:0.7269
# epoch:73, train acc:0.94, test acc:0.7183
# epoch:74, train acc:0.9466666666666667, test acc:0.7271
# epoch:75, train acc:0.9533333333333334, test acc:0.7287
# epoch:76, train acc:0.9633333333333334, test acc:0.7267
# epoch:77, train acc:0.9633333333333334, test acc:0.7293
# epoch:78, train acc:0.9733333333333334, test acc:0.7332
# epoch:79, train acc:0.9633333333333334, test acc:0.7358
# epoch:80, train acc:0.9666666666666667, test acc:0.7359
# epoch:81, train acc:0.9733333333333334, test acc:0.733
# epoch:82, train acc:0.9733333333333334, test acc:0.7354
# epoch:83, train acc:0.9766666666666667, test acc:0.7383
# epoch:84, train acc:0.9766666666666667, test acc:0.7388
# epoch:85, train acc:0.9766666666666667, test acc:0.7381
# epoch:86, train acc:0.9866666666666667, test acc:0.7357
# epoch:87, train acc:0.98, test acc:0.7392
# epoch:88, train acc:0.9833333333333333, test acc:0.7398
# epoch:89, train acc:0.9833333333333333, test acc:0.7409
# epoch:90, train acc:0.99, test acc:0.7403
# epoch:91, train acc:0.99, test acc:0.7436
# epoch:92, train acc:0.99, test acc:0.7474
# epoch:93, train acc:0.9833333333333333, test acc:0.7409
# epoch:94, train acc:0.9866666666666667, test acc:0.7403
# epoch:95, train acc:0.9866666666666667, test acc:0.7458
# epoch:96, train acc:0.99, test acc:0.746
# epoch:97, train acc:0.9966666666666667, test acc:0.7396
# epoch:98, train acc:0.9866666666666667, test acc:0.749
# epoch:99, train acc:0.99, test acc:0.7491
# epoch:100, train acc:0.9933333333333333, test acc:0.7494
# epoch:101, train acc:0.9933333333333333, test acc:0.7472
# epoch:102, train acc:0.9966666666666667, test acc:0.7498
# epoch:103, train acc:1.0, test acc:0.7473
# epoch:104, train acc:0.9966666666666667, test acc:0.7521
# epoch:105, train acc:1.0, test acc:0.7524
# epoch:106, train acc:1.0, test acc:0.751
# epoch:107, train acc:1.0, test acc:0.753
# epoch:108, train acc:0.9966666666666667, test acc:0.754
# epoch:109, train acc:0.9966666666666667, test acc:0.7548
# epoch:110, train acc:0.9966666666666667, test acc:0.7525
# epoch:111, train acc:1.0, test acc:0.7539
# epoch:112, train acc:1.0, test acc:0.751
# epoch:113, train acc:1.0, test acc:0.7521
# epoch:114, train acc:0.9966666666666667, test acc:0.7544
# epoch:115, train acc:0.9966666666666667, test acc:0.7558
# epoch:116, train acc:0.9966666666666667, test acc:0.7578
# epoch:117, train acc:0.9966666666666667, test acc:0.7544
# epoch:118, train acc:1.0, test acc:0.7559
# epoch:119, train acc:1.0, test acc:0.7574
# epoch:120, train acc:1.0, test acc:0.7573
# epoch:121, train acc:1.0, test acc:0.7554
# epoch:122, train acc:1.0, test acc:0.7592
# epoch:123, train acc:0.9966666666666667, test acc:0.759
# epoch:124, train acc:1.0, test acc:0.761
# epoch:125, train acc:0.9966666666666667, test acc:0.7612
# epoch:126, train acc:1.0, test acc:0.7576
# epoch:127, train acc:0.9966666666666667, test acc:0.7576
# epoch:128, train acc:1.0, test acc:0.7581
# epoch:129, train acc:1.0, test acc:0.7598
# epoch:130, train acc:1.0, test acc:0.7608
# epoch:131, train acc:1.0, test acc:0.7584
# epoch:132, train acc:1.0, test acc:0.7566
# epoch:133, train acc:1.0, test acc:0.7604
# epoch:134, train acc:1.0, test acc:0.7621
# epoch:135, train acc:1.0, test acc:0.7614
# epoch:136, train acc:1.0, test acc:0.7622
# epoch:137, train acc:1.0, test acc:0.7635
# epoch:138, train acc:1.0, test acc:0.7638
# epoch:139, train acc:1.0, test acc:0.7645
# epoch:140, train acc:1.0, test acc:0.7644
# epoch:141, train acc:1.0, test acc:0.7652
# epoch:142, train acc:1.0, test acc:0.764
# epoch:143, train acc:1.0, test acc:0.7654
# epoch:144, train acc:1.0, test acc:0.7672
# epoch:145, train acc:1.0, test acc:0.7663
# epoch:146, train acc:1.0, test acc:0.7654
# epoch:147, train acc:1.0, test acc:0.7644
# epoch:148, train acc:1.0, test acc:0.7661
# epoch:149, train acc:1.0, test acc:0.7667
# epoch:150, train acc:1.0, test acc:0.7661
# epoch:151, train acc:1.0, test acc:0.7673
# epoch:152, train acc:1.0, test acc:0.7662
# epoch:153, train acc:1.0, test acc:0.7661
# epoch:154, train acc:1.0, test acc:0.7655
# epoch:155, train acc:1.0, test acc:0.7659
# epoch:156, train acc:1.0, test acc:0.7664
# epoch:157, train acc:1.0, test acc:0.7651
# epoch:158, train acc:1.0, test acc:0.765
# epoch:159, train acc:1.0, test acc:0.7672
# epoch:160, train acc:1.0, test acc:0.7658
# epoch:161, train acc:1.0, test acc:0.7655
# epoch:162, train acc:1.0, test acc:0.7651
# epoch:163, train acc:1.0, test acc:0.7654
# epoch:164, train acc:1.0, test acc:0.7668
# epoch:165, train acc:1.0, test acc:0.7672
# epoch:166, train acc:1.0, test acc:0.769
# epoch:167, train acc:1.0, test acc:0.7664
# epoch:168, train acc:1.0, test acc:0.7684
# epoch:169, train acc:1.0, test acc:0.7692
# epoch:170, train acc:1.0, test acc:0.7671
# epoch:171, train acc:1.0, test acc:0.7669
# epoch:172, train acc:1.0, test acc:0.769
# epoch:173, train acc:1.0, test acc:0.7691
# epoch:174, train acc:1.0, test acc:0.7685
# epoch:175, train acc:1.0, test acc:0.7681
# epoch:176, train acc:1.0, test acc:0.7685
# epoch:177, train acc:1.0, test acc:0.7685
# epoch:178, train acc:1.0, test acc:0.7682
# epoch:179, train acc:1.0, test acc:0.7676
# epoch:180, train acc:1.0, test acc:0.7669
# epoch:181, train acc:1.0, test acc:0.7682
# epoch:182, train acc:1.0, test acc:0.7681
# epoch:183, train acc:1.0, test acc:0.7689
# epoch:184, train acc:1.0, test acc:0.7687
# epoch:185, train acc:1.0, test acc:0.7698
# epoch:186, train acc:1.0, test acc:0.7682
# epoch:187, train acc:1.0, test acc:0.7697
# epoch:188, train acc:1.0, test acc:0.7687
# epoch:189, train acc:1.0, test acc:0.77
# epoch:190, train acc:1.0, test acc:0.7693
# epoch:191, train acc:1.0, test acc:0.7687
# epoch:192, train acc:1.0, test acc:0.7683
# epoch:193, train acc:1.0, test acc:0.7691
# epoch:194, train acc:1.0, test acc:0.7684
# epoch:195, train acc:1.0, test acc:0.7701
# epoch:196, train acc:1.0, test acc:0.77
# epoch:197, train acc:1.0, test acc:0.7706
# epoch:198, train acc:1.0, test acc:0.7702
# epoch:199, train acc:1.0, test acc:0.7712
# epoch:200, train acc:1.0, test acc:0.7701

# %%
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ### Weight Decay

# %%
#overfitting has occurred
weight_decay_lambda = 0.1

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01)

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break
# Out:
# epoch:0, train acc:0.08333333333333333, test acc:0.0729
# epoch:1, train acc:0.1, test acc:0.0869
# epoch:2, train acc:0.11666666666666667, test acc:0.1054
# epoch:3, train acc:0.15, test acc:0.1173
# epoch:4, train acc:0.16333333333333333, test acc:0.1292
# epoch:5, train acc:0.19333333333333333, test acc:0.1354
# epoch:6, train acc:0.19666666666666666, test acc:0.1411
# epoch:7, train acc:0.21666666666666667, test acc:0.1501
# epoch:8, train acc:0.22333333333333333, test acc:0.1532
# epoch:9, train acc:0.23666666666666666, test acc:0.1599
# epoch:10, train acc:0.24, test acc:0.165
# epoch:11, train acc:0.27, test acc:0.1715
# epoch:12, train acc:0.26666666666666666, test acc:0.1779
# epoch:13, train acc:0.27666666666666667, test acc:0.1869
# epoch:14, train acc:0.2866666666666667, test acc:0.1946
# epoch:15, train acc:0.33, test acc:0.2082
# epoch:16, train acc:0.3433333333333333, test acc:0.2247
# epoch:17, train acc:0.3933333333333333, test acc:0.2416
# epoch:18, train acc:0.4166666666666667, test acc:0.2577
# epoch:19, train acc:0.42333333333333334, test acc:0.2623
# epoch:20, train acc:0.4066666666666667, test acc:0.2702
# epoch:21, train acc:0.4, test acc:0.2578
# epoch:22, train acc:0.38666666666666666, test acc:0.2522
# epoch:23, train acc:0.4, test acc:0.2578
# epoch:24, train acc:0.39666666666666667, test acc:0.2771
# epoch:25, train acc:0.4166666666666667, test acc:0.2839
# epoch:26, train acc:0.42333333333333334, test acc:0.2926
# epoch:27, train acc:0.43666666666666665, test acc:0.3014
# epoch:28, train acc:0.45666666666666667, test acc:0.32
# epoch:29, train acc:0.47, test acc:0.3236
# epoch:30, train acc:0.4666666666666667, test acc:0.3387
# epoch:31, train acc:0.4766666666666667, test acc:0.3342
# epoch:32, train acc:0.49, test acc:0.3517
# epoch:33, train acc:0.51, test acc:0.3527
# epoch:34, train acc:0.49333333333333335, test acc:0.3507
# epoch:35, train acc:0.49666666666666665, test acc:0.3567
# epoch:36, train acc:0.53, test acc:0.3695
# epoch:37, train acc:0.5333333333333333, test acc:0.377
# epoch:38, train acc:0.54, test acc:0.3777
# epoch:39, train acc:0.5366666666666666, test acc:0.3774
# epoch:40, train acc:0.5333333333333333, test acc:0.3865
# epoch:41, train acc:0.57, test acc:0.4187
# epoch:42, train acc:0.5666666666666667, test acc:0.4199
# epoch:43, train acc:0.5733333333333334, test acc:0.4248
# epoch:44, train acc:0.6, test acc:0.4352
# epoch:45, train acc:0.59, test acc:0.4369
# epoch:46, train acc:0.5766666666666667, test acc:0.4354
# epoch:47, train acc:0.5833333333333334, test acc:0.4409
# epoch:48, train acc:0.5766666666666667, test acc:0.4429
# epoch:49, train acc:0.5833333333333334, test acc:0.4506
# epoch:50, train acc:0.6066666666666667, test acc:0.4673
# epoch:51, train acc:0.6, test acc:0.4703
# epoch:52, train acc:0.61, test acc:0.4815
# epoch:53, train acc:0.64, test acc:0.4978
# epoch:54, train acc:0.65, test acc:0.5081
# epoch:55, train acc:0.6433333333333333, test acc:0.5142
# epoch:56, train acc:0.66, test acc:0.5232
# epoch:57, train acc:0.6666666666666666, test acc:0.5257
# epoch:58, train acc:0.6533333333333333, test acc:0.5156
# epoch:59, train acc:0.6733333333333333, test acc:0.5288
# epoch:60, train acc:0.6766666666666666, test acc:0.5364
# epoch:61, train acc:0.6933333333333334, test acc:0.5378
# epoch:62, train acc:0.69, test acc:0.5436
# epoch:63, train acc:0.71, test acc:0.5495
# epoch:64, train acc:0.69, test acc:0.5449
# epoch:65, train acc:0.6966666666666667, test acc:0.5546
# epoch:66, train acc:0.7166666666666667, test acc:0.5739
# epoch:67, train acc:0.7233333333333334, test acc:0.5753
# epoch:68, train acc:0.7166666666666667, test acc:0.5724
# epoch:69, train acc:0.74, test acc:0.5849
# epoch:70, train acc:0.7366666666666667, test acc:0.5915
# epoch:71, train acc:0.7366666666666667, test acc:0.5925
# epoch:72, train acc:0.7633333333333333, test acc:0.6027
# epoch:73, train acc:0.7433333333333333, test acc:0.595
# epoch:74, train acc:0.7733333333333333, test acc:0.6023
# epoch:75, train acc:0.7666666666666667, test acc:0.6026
# epoch:76, train acc:0.7566666666666667, test acc:0.5987
# epoch:77, train acc:0.77, test acc:0.6015
# epoch:78, train acc:0.77, test acc:0.6029
# epoch:79, train acc:0.7333333333333333, test acc:0.5857
# epoch:80, train acc:0.74, test acc:0.5946
# epoch:81, train acc:0.7666666666666667, test acc:0.6094
# epoch:82, train acc:0.7633333333333333, test acc:0.6109
# epoch:83, train acc:0.7766666666666666, test acc:0.6134
# epoch:84, train acc:0.7733333333333333, test acc:0.6254
# epoch:85, train acc:0.7733333333333333, test acc:0.6098
# epoch:86, train acc:0.7866666666666666, test acc:0.6185
# epoch:87, train acc:0.7933333333333333, test acc:0.6213
# epoch:88, train acc:0.79, test acc:0.6119
# epoch:89, train acc:0.79, test acc:0.6189
# epoch:90, train acc:0.8, test acc:0.6175
# epoch:91, train acc:0.8, test acc:0.6397
# epoch:92, train acc:0.8166666666666667, test acc:0.6421
# epoch:93, train acc:0.8233333333333334, test acc:0.6417
# epoch:94, train acc:0.8133333333333334, test acc:0.6462
# epoch:95, train acc:0.81, test acc:0.6371
# epoch:96, train acc:0.82, test acc:0.6395
# epoch:97, train acc:0.7966666666666666, test acc:0.6442
# epoch:98, train acc:0.8, test acc:0.6352
# epoch:99, train acc:0.8166666666666667, test acc:0.6434
# epoch:100, train acc:0.8033333333333333, test acc:0.6387
# epoch:101, train acc:0.79, test acc:0.6402
# epoch:102, train acc:0.81, test acc:0.6435
# epoch:103, train acc:0.84, test acc:0.6575
# epoch:104, train acc:0.8266666666666667, test acc:0.6618
# epoch:105, train acc:0.8333333333333334, test acc:0.6698
# epoch:106, train acc:0.8233333333333334, test acc:0.6536
# epoch:107, train acc:0.8133333333333334, test acc:0.6514
# epoch:108, train acc:0.83, test acc:0.6681
# epoch:109, train acc:0.83, test acc:0.6606
# epoch:110, train acc:0.84, test acc:0.6675
# epoch:111, train acc:0.84, test acc:0.6661
# epoch:112, train acc:0.82, test acc:0.6513
# epoch:113, train acc:0.8366666666666667, test acc:0.6632
# epoch:114, train acc:0.81, test acc:0.6505
# epoch:115, train acc:0.8266666666666667, test acc:0.6562
# epoch:116, train acc:0.8433333333333334, test acc:0.6647
# epoch:117, train acc:0.8466666666666667, test acc:0.6738
# epoch:118, train acc:0.86, test acc:0.6798
# epoch:119, train acc:0.8466666666666667, test acc:0.6683
# epoch:120, train acc:0.83, test acc:0.6678
# epoch:121, train acc:0.8233333333333334, test acc:0.6636
# epoch:122, train acc:0.85, test acc:0.6733
# epoch:123, train acc:0.8466666666666667, test acc:0.676
# epoch:124, train acc:0.84, test acc:0.6686
# epoch:125, train acc:0.8366666666666667, test acc:0.677
# epoch:126, train acc:0.8433333333333334, test acc:0.6749
# epoch:127, train acc:0.8566666666666667, test acc:0.685
# epoch:128, train acc:0.8566666666666667, test acc:0.6828
# epoch:129, train acc:0.8566666666666667, test acc:0.6791
# epoch:130, train acc:0.8366666666666667, test acc:0.662
# epoch:131, train acc:0.82, test acc:0.6656
# epoch:132, train acc:0.8433333333333334, test acc:0.6767
# epoch:133, train acc:0.86, test acc:0.6751
# epoch:134, train acc:0.8366666666666667, test acc:0.6748
# epoch:135, train acc:0.8466666666666667, test acc:0.6779
# epoch:136, train acc:0.8566666666666667, test acc:0.6839
# epoch:137, train acc:0.8666666666666667, test acc:0.69
# epoch:138, train acc:0.86, test acc:0.6722
# epoch:139, train acc:0.8633333333333333, test acc:0.693
# epoch:140, train acc:0.87, test acc:0.6931
# epoch:141, train acc:0.8633333333333333, test acc:0.6903
# epoch:142, train acc:0.8566666666666667, test acc:0.6851
# epoch:143, train acc:0.8666666666666667, test acc:0.6908
# epoch:144, train acc:0.8566666666666667, test acc:0.6841
# epoch:145, train acc:0.8666666666666667, test acc:0.6986
# epoch:146, train acc:0.87, test acc:0.6919
# epoch:147, train acc:0.86, test acc:0.6943
# epoch:148, train acc:0.8733333333333333, test acc:0.6955
# epoch:149, train acc:0.87, test acc:0.6885
# epoch:150, train acc:0.87, test acc:0.6915
# epoch:151, train acc:0.8666666666666667, test acc:0.685
# epoch:152, train acc:0.8566666666666667, test acc:0.691
# epoch:153, train acc:0.8733333333333333, test acc:0.6977
# epoch:154, train acc:0.87, test acc:0.6957
# epoch:155, train acc:0.87, test acc:0.6962
# epoch:156, train acc:0.8733333333333333, test acc:0.6962
# epoch:157, train acc:0.86, test acc:0.6859
# epoch:158, train acc:0.85, test acc:0.6856
# epoch:159, train acc:0.8533333333333334, test acc:0.6771
# epoch:160, train acc:0.8566666666666667, test acc:0.6892
# epoch:161, train acc:0.8533333333333334, test acc:0.6864
# epoch:162, train acc:0.8566666666666667, test acc:0.6896
# epoch:163, train acc:0.8566666666666667, test acc:0.6828
# epoch:164, train acc:0.8633333333333333, test acc:0.6852
# epoch:165, train acc:0.85, test acc:0.6818
# epoch:166, train acc:0.8433333333333334, test acc:0.6844
# epoch:167, train acc:0.8466666666666667, test acc:0.6853
# epoch:168, train acc:0.86, test acc:0.6892
# epoch:169, train acc:0.8633333333333333, test acc:0.6882
# epoch:170, train acc:0.8633333333333333, test acc:0.6868
# epoch:171, train acc:0.8633333333333333, test acc:0.6939
# epoch:172, train acc:0.8566666666666667, test acc:0.6911
# epoch:173, train acc:0.86, test acc:0.6897
# epoch:174, train acc:0.8666666666666667, test acc:0.6978
# epoch:175, train acc:0.8733333333333333, test acc:0.7024
# epoch:176, train acc:0.8533333333333334, test acc:0.6953
# epoch:177, train acc:0.8766666666666667, test acc:0.6895
# epoch:178, train acc:0.8833333333333333, test acc:0.7026
# epoch:179, train acc:0.8666666666666667, test acc:0.6985
# epoch:180, train acc:0.88, test acc:0.7055
# epoch:181, train acc:0.88, test acc:0.709
# epoch:182, train acc:0.8733333333333333, test acc:0.6982
# epoch:183, train acc:0.8766666666666667, test acc:0.7038
# epoch:184, train acc:0.87, test acc:0.7035
# epoch:185, train acc:0.88, test acc:0.7019
# epoch:186, train acc:0.88, test acc:0.7027
# epoch:187, train acc:0.8733333333333333, test acc:0.701
# epoch:188, train acc:0.88, test acc:0.7063
# epoch:189, train acc:0.8766666666666667, test acc:0.7012
# epoch:190, train acc:0.8733333333333333, test acc:0.7008
# epoch:191, train acc:0.8633333333333333, test acc:0.6979
# epoch:192, train acc:0.88, test acc:0.708
# epoch:193, train acc:0.8733333333333333, test acc:0.7035
# epoch:194, train acc:0.8766666666666667, test acc:0.7048
# epoch:195, train acc:0.88, test acc:0.7038
# epoch:196, train acc:0.8766666666666667, test acc:0.7054
# epoch:197, train acc:0.8866666666666667, test acc:0.7068
# epoch:198, train acc:0.87, test acc:0.6961
# epoch:199, train acc:0.8733333333333333, test acc:0.7028
# epoch:200, train acc:0.8733333333333333, test acc:0.7016

# %%
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## Dropout

# %%
class Dropout:
    def __init__(self, dropout_ratio=0.5):
        self.dropout_ratio = dropout_ratio
        self.mask = None
        
    def forward(self, x, train_flg=True):
        if(train_flg):
            self.mask = np.random.rand(*x.shape) > self.dropout_ratio
            return x*self.mask
        return x*(1.0-self.dropout_ratio)
    def backward(self, dout):
        return dout*self.mask

# %%
#using dropout
from common.trainer import Trainer #using trainer -> calles forward and backward!

use_dropout = True 
dropout_ratio = 0.2


network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                              output_size=10, use_dropout=use_dropout, dropout_ration=dropout_ratio)
trainer = Trainer(network, x_train, t_train, x_test, t_test,
                  epochs=301, mini_batch_size=100,
                  optimizer='sgd', optimizer_param={'lr': 0.01}, verbose=True)
trainer.train()

train_acc_list, test_acc_list = trainer.train_acc_list, trainer.test_acc_list
# Out:
# train loss:2.305685814835605
# === epoch:1, train acc:0.056666666666666664, test acc:0.061 ===
# train loss:2.298284020534764
# train loss:2.2880734214755956
# train loss:2.305959933981604
# === epoch:2, train acc:0.06333333333333334, test acc:0.0621 ===
# train loss:2.2985906447551354
# train loss:2.2994077041765975
# train loss:2.2993187972619413
# === epoch:3, train acc:0.06, test acc:0.0654 ===
# train loss:2.3019384158664122
# train loss:2.302575273710379
# train loss:2.291793564864825
# === epoch:4, train acc:0.07, test acc:0.0676 ===
# train loss:2.303106900670162
# train loss:2.2942952001652603
# train loss:2.297247752752589
# === epoch:5, train acc:0.07333333333333333, test acc:0.0689 ===
# train loss:2.3131340916106877
# train loss:2.3064674910601557
# train loss:2.278383288275622
# === epoch:6, train acc:0.07333333333333333, test acc:0.0707 ===
# train loss:2.2903899493136852
# train loss:2.288139711078462
# train loss:2.2871607838145946
# === epoch:7, train acc:0.08666666666666667, test acc:0.0706 ===
# train loss:2.3015901685607147
# train loss:2.2933470900135875
# train loss:2.287133536920596
# === epoch:8, train acc:0.08666666666666667, test acc:0.0725 ===
# train loss:2.300611759067232
# train loss:2.3059812884000794
# train loss:2.296826499464978
# === epoch:9, train acc:0.08333333333333333, test acc:0.0774 ===
# train loss:2.2954107772008774
# train loss:2.2912606802207414
# train loss:2.298623324262407
# === epoch:10, train acc:0.09, test acc:0.0786 ===
# train loss:2.293901116078493
# train loss:2.2949279123646558
# train loss:2.292541506712244
# === epoch:11, train acc:0.08666666666666667, test acc:0.0822 ===
# train loss:2.2912008506927375
# train loss:2.282231542907695
# train loss:2.271324200960332
# === epoch:12, train acc:0.09, test acc:0.0838 ===
# train loss:2.2791803435908933
# train loss:2.284200942265859
# train loss:2.2817149755865502
# === epoch:13, train acc:0.09333333333333334, test acc:0.0876 ===
# train loss:2.2770413472172915
# train loss:2.2918773015416134
# train loss:2.283778526562983
# === epoch:14, train acc:0.09333333333333334, test acc:0.0902 ===
# train loss:2.2910121930331506
# train loss:2.2797416249300513
# train loss:2.2819340843016294
# === epoch:15, train acc:0.09666666666666666, test acc:0.092 ===
# train loss:2.2935649339872057
# train loss:2.2768966043022747
# train loss:2.300153773666566
# === epoch:16, train acc:0.09666666666666666, test acc:0.0937 ===
# train loss:2.279682006147363
# train loss:2.2802180137182835
# train loss:2.2835299847490234
# === epoch:17, train acc:0.1, test acc:0.0945 ===
# train loss:2.2607241091852273
# train loss:2.2868351005996854
# train loss:2.292953710248365
# === epoch:18, train acc:0.10333333333333333, test acc:0.0964 ===
# train loss:2.283762849955294
# train loss:2.2839720844298026
# train loss:2.2867424661575195
# === epoch:19, train acc:0.10333333333333333, test acc:0.0968 ===
# train loss:2.2762767243100464
# train loss:2.2748453612810597
# train loss:2.291566957039956
# === epoch:20, train acc:0.09666666666666666, test acc:0.0978 ===
# train loss:2.2757002408887717
# train loss:2.285059453756461
# train loss:2.2873680840097186
# === epoch:21, train acc:0.09666666666666666, test acc:0.1012 ===
# train loss:2.2814742890477446
# train loss:2.2783167753345945
# train loss:2.2753225898428164
# === epoch:22, train acc:0.09, test acc:0.1025 ===
# train loss:2.288557946456024
# train loss:2.2664510633193102
# train loss:2.2753648647863716
# === epoch:23, train acc:0.09, test acc:0.104 ===
# train loss:2.275961439447007
# train loss:2.2845171885903808
# train loss:2.2707628975532597
# === epoch:24, train acc:0.09333333333333334, test acc:0.1059 ===
# train loss:2.286408446435587
# train loss:2.281920318487418
# train loss:2.2590445113225384
# === epoch:25, train acc:0.09666666666666666, test acc:0.1085 ===
# train loss:2.276408305653263
# train loss:2.2707636719200113
# train loss:2.276170375007896
# === epoch:26, train acc:0.09, test acc:0.1103 ===
# train loss:2.278348780911083
# train loss:2.2649563578438534
# train loss:2.29967300568669
# === epoch:27, train acc:0.1, test acc:0.1119 ===
# train loss:2.2650341883413954
# train loss:2.267425151853744
# train loss:2.2721535483962794
# === epoch:28, train acc:0.09666666666666666, test acc:0.112 ===
# train loss:2.267102059009108
# train loss:2.275440307020385
# train loss:2.2760097365779357
# === epoch:29, train acc:0.11333333333333333, test acc:0.1117 ===
# train loss:2.273261478010714
# train loss:2.277299406491386
# train loss:2.276874237236139
# === epoch:30, train acc:0.10666666666666667, test acc:0.1161 ===
# train loss:2.277916412938216
# train loss:2.285654908053142
# train loss:2.2763386578212588
# === epoch:31, train acc:0.12666666666666668, test acc:0.1167 ===
# train loss:2.2845760380630633
# train loss:2.2687209217369597
# train loss:2.2828296338002
# === epoch:32, train acc:0.13, test acc:0.119 ===
# train loss:2.261680589662732
# train loss:2.259789566909446
# train loss:2.2725430787976824
# === epoch:33, train acc:0.13333333333333333, test acc:0.1198 ===
# train loss:2.271307835214126
# train loss:2.276394076669129
# train loss:2.276893268932776
# === epoch:34, train acc:0.13666666666666666, test acc:0.1213 ===
# train loss:2.2753009836283016
# train loss:2.269054709215518
# train loss:2.269573995800448
# === epoch:35, train acc:0.13666666666666666, test acc:0.1219 ===
# train loss:2.2718053290033136
# train loss:2.270675605278247
# train loss:2.265224765081435
# === epoch:36, train acc:0.14666666666666667, test acc:0.1237 ===
# train loss:2.2634486130172298
# train loss:2.2743228468353753
# train loss:2.276633111767746
# === epoch:37, train acc:0.14666666666666667, test acc:0.1276 ===
# train loss:2.26742254570968
# train loss:2.274202342025199
# train loss:2.269259919647311
# === epoch:38, train acc:0.15, test acc:0.1302 ===
# train loss:2.249844453338175
# train loss:2.2663170532536383
# train loss:2.26005524108436
# === epoch:39, train acc:0.15, test acc:0.1283 ===
# train loss:2.2645420665796783
# train loss:2.260718095190645
# train loss:2.2682416553457383
# === epoch:40, train acc:0.14666666666666667, test acc:0.1307 ===
# train loss:2.257387899594462
# train loss:2.2639119343072425
# train loss:2.259974690422778
# === epoch:41, train acc:0.14333333333333334, test acc:0.1275 ===
# train loss:2.2803369533135087
# train loss:2.2514162424454804
# train loss:2.2533946381637215
# === epoch:42, train acc:0.14333333333333334, test acc:0.1302 ===
# train loss:2.2660137928509694
# train loss:2.264792189136353
# train loss:2.2505475350501127
# === epoch:43, train acc:0.14, test acc:0.1278 ===
# train loss:2.2654642697070404
# train loss:2.258885794631758
# train loss:2.2636464546309147
# === epoch:44, train acc:0.14666666666666667, test acc:0.1344 ===
# train loss:2.2560313768862574
# train loss:2.253708179132812
# train loss:2.26630501161611
# === epoch:45, train acc:0.14666666666666667, test acc:0.1404 ===
# train loss:2.267505861557577
# train loss:2.266258427620504
# train loss:2.2574913994385355
# === epoch:46, train acc:0.14666666666666667, test acc:0.1427 ===
# train loss:2.270212034604315
# train loss:2.2505737081477095
# train loss:2.2656879119025315
# === epoch:47, train acc:0.15666666666666668, test acc:0.1462 ===
# train loss:2.2598267436147537
# train loss:2.257637152903422
# train loss:2.2597280255655234
# === epoch:48, train acc:0.16, test acc:0.1461 ===
# train loss:2.2695073724899966
# train loss:2.2455054497564135
# train loss:2.2590274510698665
# === epoch:49, train acc:0.15333333333333332, test acc:0.1431 ===
# train loss:2.246813497191919
# train loss:2.260495541593241
# train loss:2.246990114152482
# === epoch:50, train acc:0.15333333333333332, test acc:0.1418 ===
# train loss:2.2573219096041854
# train loss:2.2579196595962596
# train loss:2.2600493418548
# === epoch:51, train acc:0.15666666666666668, test acc:0.1444 ===
# train loss:2.261156694607659
# train loss:2.2528073032378093
# train loss:2.2399078408493103
# === epoch:52, train acc:0.17, test acc:0.1477 ===
# train loss:2.26237373504908
# train loss:2.2516349670369964
# train loss:2.2523912077483157
# === epoch:53, train acc:0.17333333333333334, test acc:0.1522 ===
# train loss:2.2609097964825953
# train loss:2.2488705494281964
# train loss:2.251344522132583
# === epoch:54, train acc:0.17333333333333334, test acc:0.1526 ===
# train loss:2.2508304626877025
# train loss:2.266695089126732
# train loss:2.2402558985629977
# === epoch:55, train acc:0.17333333333333334, test acc:0.154 ===
# train loss:2.2465174600011464
# train loss:2.245643049396553
# train loss:2.242255819274389
# === epoch:56, train acc:0.17333333333333334, test acc:0.151 ===
# train loss:2.2374365657780793
# train loss:2.2432872467582223
# train loss:2.257969052041656
# === epoch:57, train acc:0.18666666666666668, test acc:0.1567 ===
# train loss:2.2479645553541214
# train loss:2.237721991773359
# train loss:2.2296827241419694
# === epoch:58, train acc:0.18333333333333332, test acc:0.1552 ===
# train loss:2.230902883760247
# train loss:2.258408245784664
# train loss:2.2346409487963474
# === epoch:59, train acc:0.18333333333333332, test acc:0.1537 ===
# train loss:2.246083217405088
# train loss:2.257555302951299
# train loss:2.2317260390669853
# === epoch:60, train acc:0.19333333333333333, test acc:0.1571 ===
# train loss:2.2423381697011138
# train loss:2.2388428567530276
# train loss:2.266540311635523
# === epoch:61, train acc:0.19333333333333333, test acc:0.1602 ===
# train loss:2.23340395466598
# train loss:2.2376681595699535
# train loss:2.2444489353391286
# === epoch:62, train acc:0.19333333333333333, test acc:0.1633 ===
# train loss:2.250978965987137
# train loss:2.2654885061479906
# train loss:2.2295813034390233
# === epoch:63, train acc:0.19333333333333333, test acc:0.1673 ===
# train loss:2.249062803681832
# train loss:2.248595613616842
# train loss:2.2392888275000877
# === epoch:64, train acc:0.19666666666666666, test acc:0.1735 ===
# train loss:2.241861679271247
# train loss:2.237805860394872
# train loss:2.2305400937303164
# === epoch:65, train acc:0.21, test acc:0.1753 ===
# train loss:2.2483068282999024
# train loss:2.2323842939366147
# train loss:2.22666665353835
# === epoch:66, train acc:0.21, test acc:0.1759 ===
# train loss:2.247800268838808
# train loss:2.2135333377457083
# train loss:2.2302913823495953
# === epoch:67, train acc:0.21666666666666667, test acc:0.1786 ===
# train loss:2.224595426458096
# train loss:2.220280256984307
# train loss:2.262670433324106
# === epoch:68, train acc:0.22, test acc:0.1829 ===
# train loss:2.2462007679385567
# train loss:2.2217726688910444
# train loss:2.218009369466246
# === epoch:69, train acc:0.22, test acc:0.1822 ===
# train loss:2.227832503008594
# train loss:2.2380055281750004
# train loss:2.2263096634823705
# === epoch:70, train acc:0.22, test acc:0.1852 ===
# train loss:2.2448660441188464
# train loss:2.2205929673445697
# train loss:2.236530126330628
# === epoch:71, train acc:0.22333333333333333, test acc:0.1866 ===
# train loss:2.2219791872168937
# train loss:2.225311427891452
# train loss:2.224552424543754
# === epoch:72, train acc:0.22333333333333333, test acc:0.1886 ===
# train loss:2.2553828861582477
# train loss:2.2162949521849704
# train loss:2.2238288258680226
# === epoch:73, train acc:0.22333333333333333, test acc:0.1909 ===
# train loss:2.243919155767338
# train loss:2.2017512031943975
# train loss:2.225147968081795
# === epoch:74, train acc:0.22666666666666666, test acc:0.1916 ===
# train loss:2.219009268203331
# train loss:2.1824412754996745
# train loss:2.205667880991237
# === epoch:75, train acc:0.22333333333333333, test acc:0.1879 ===
# train loss:2.25227223091957
# train loss:2.2269567242281028
# train loss:2.229540800998108
# === epoch:76, train acc:0.22333333333333333, test acc:0.1894 ===
# train loss:2.2265377916839775
# train loss:2.225316345614039
# train loss:2.205840566493913
# === epoch:77, train acc:0.22666666666666666, test acc:0.1922 ===
# train loss:2.2012621923622095
# train loss:2.2214484396327974
# train loss:2.1873474117864347
# === epoch:78, train acc:0.22, test acc:0.1881 ===
# train loss:2.212846276523363
# train loss:2.237733218012867
# train loss:2.2162369114866807
# === epoch:79, train acc:0.22666666666666666, test acc:0.1933 ===
# train loss:2.208371726208341
# train loss:2.2211921352482635
# train loss:2.2081410305615132
# === epoch:80, train acc:0.22666666666666666, test acc:0.1951 ===
# train loss:2.2253388705565995
# train loss:2.208177604893729
# train loss:2.203661331494818
# === epoch:81, train acc:0.22666666666666666, test acc:0.1942 ===
# train loss:2.1994279385114175
# train loss:2.2180766599860084
# train loss:2.173907928669597
# === epoch:82, train acc:0.22666666666666666, test acc:0.1952 ===
# train loss:2.2107878499411524
# train loss:2.241528636045078
# train loss:2.2037673566392386
# === epoch:83, train acc:0.22666666666666666, test acc:0.1974 ===
# train loss:2.1983373859434754
# train loss:2.1906552153809398
# train loss:2.1849753845507673
# === epoch:84, train acc:0.22333333333333333, test acc:0.197 ===
# train loss:2.204815746572599
# train loss:2.1908383190325473
# train loss:2.2101532216121154
# === epoch:85, train acc:0.22333333333333333, test acc:0.1972 ===
# train loss:2.2012607628622267
# train loss:2.232431431835671
# train loss:2.2165453847117145
# === epoch:86, train acc:0.22, test acc:0.1995 ===
# train loss:2.205677472128246
# train loss:2.2137965705971636
# train loss:2.2099227284637237
# === epoch:87, train acc:0.22666666666666666, test acc:0.2008 ===
# train loss:2.2247651830341244
# train loss:2.2021086067114863
# train loss:2.1703078437601184
# === epoch:88, train acc:0.22666666666666666, test acc:0.2015 ===
# train loss:2.204041207424565
# train loss:2.1969992683738955
# train loss:2.176348099262123
# === epoch:89, train acc:0.22666666666666666, test acc:0.2025 ===
# train loss:2.215127438348653
# train loss:2.180002958725338
# train loss:2.2127673083390484
# === epoch:90, train acc:0.22666666666666666, test acc:0.2045 ===
# train loss:2.210006894734934
# train loss:2.1977084028765397
# train loss:2.209872911303533
# === epoch:91, train acc:0.22666666666666666, test acc:0.2056 ===
# train loss:2.1835501297349933
# train loss:2.1905864415217744
# train loss:2.1989979729597438
# === epoch:92, train acc:0.22666666666666666, test acc:0.2062 ===
# train loss:2.2063751025675815
# train loss:2.1733241480039727
# train loss:2.1764120265410987
# === epoch:93, train acc:0.22666666666666666, test acc:0.2051 ===
# train loss:2.182986833726484
# train loss:2.1951986933962013
# train loss:2.2178031786781225
# === epoch:94, train acc:0.22666666666666666, test acc:0.2061 ===
# train loss:2.1514798703184073
# train loss:2.20478962790448
# train loss:2.1855385337812656
# === epoch:95, train acc:0.22666666666666666, test acc:0.2056 ===
# train loss:2.1893573474987447
# train loss:2.198780434928145
# train loss:2.2000887589073965
# === epoch:96, train acc:0.23, test acc:0.2075 ===
# train loss:2.191114245789693
# train loss:2.141772169175151
# train loss:2.144852610029217
# === epoch:97, train acc:0.23, test acc:0.2078 ===
# train loss:2.2223901040608793
# train loss:2.1675888610418705
# train loss:2.1832625578039786
# === epoch:98, train acc:0.23, test acc:0.2083 ===
# train loss:2.1557319420690053
# train loss:2.1795976392360585
# train loss:2.171694188380921
# === epoch:99, train acc:0.23, test acc:0.2077 ===
# train loss:2.177976164246973
# train loss:2.170581402291832
# train loss:2.206970529401003
# === epoch:100, train acc:0.23, test acc:0.2079 ===
# train loss:2.220865900028142
# train loss:2.14315293692531
# train loss:2.145042855930317
# === epoch:101, train acc:0.23, test acc:0.2085 ===
# train loss:2.1663813373845344
# train loss:2.2067958806917116
# train loss:2.1906096285174117
# === epoch:102, train acc:0.23333333333333334, test acc:0.2099 ===
# train loss:2.1837392746650917
# train loss:2.171293247912894
# train loss:2.1298210253742975
# === epoch:103, train acc:0.23333333333333334, test acc:0.2106 ===
# train loss:2.1666405434721274
# train loss:2.1720423819611514
# train loss:2.1390758084823154
# === epoch:104, train acc:0.23333333333333334, test acc:0.2109 ===
# train loss:2.1641673680798177
# train loss:2.173987114281108
# train loss:2.1815875301210155
# === epoch:105, train acc:0.23666666666666666, test acc:0.2121 ===
# train loss:2.1559904761406203
# train loss:2.1642782614757197
# train loss:2.1549667392999377
# === epoch:106, train acc:0.23666666666666666, test acc:0.2121 ===
# train loss:2.164813777252941
# train loss:2.1683851324264767
# train loss:2.1574352948622897
# === epoch:107, train acc:0.23666666666666666, test acc:0.2123 ===
# train loss:2.1809233115511306
# train loss:2.1861082144922936
# train loss:2.1734862520375344
# === epoch:108, train acc:0.24, test acc:0.214 ===
# train loss:2.1726786243620615
# train loss:2.1686834304590836
# train loss:2.1410648902707514
# === epoch:109, train acc:0.24, test acc:0.2147 ===
# train loss:2.1714812420884275
# train loss:2.1523155217581493
# train loss:2.175640612429056
# === epoch:110, train acc:0.23666666666666666, test acc:0.2151 ===
# train loss:2.131648530323647
# train loss:2.1950393984675327
# train loss:2.1333594673672436
# === epoch:111, train acc:0.24, test acc:0.2151 ===
# train loss:2.166479795151598
# train loss:2.1382750407693756
# train loss:2.193187377495091
# === epoch:112, train acc:0.24, test acc:0.2171 ===
# train loss:2.124296299594272
# train loss:2.155549513403528
# train loss:2.1837296628330907
# === epoch:113, train acc:0.24, test acc:0.2185 ===
# train loss:2.1803024888082696
# train loss:2.1624080934234704
# train loss:2.1551898507967158
# === epoch:114, train acc:0.24666666666666667, test acc:0.2213 ===
# train loss:2.0957121642241407
# train loss:2.104819773510242
# train loss:2.1321267118211007
# === epoch:115, train acc:0.24333333333333335, test acc:0.2205 ===
# train loss:2.0888520537959927
# train loss:2.0920830810921482
# train loss:2.1671905540693195
# === epoch:116, train acc:0.24333333333333335, test acc:0.2182 ===
# train loss:2.168635622498179
# train loss:2.148330551199577
# train loss:2.1487935606927953
# === epoch:117, train acc:0.24333333333333335, test acc:0.2192 ===
# train loss:2.140979950937185
# train loss:2.1023315934527456
# train loss:2.133643103827851
# === epoch:118, train acc:0.24666666666666667, test acc:0.2203 ===
# train loss:2.1534761981544275
# train loss:2.0818918510677156
# train loss:2.162048813407421
# === epoch:119, train acc:0.24666666666666667, test acc:0.2215 ===
# train loss:2.0896907350611014
# train loss:2.1664245542479117
# train loss:2.1091887206948106
# === epoch:120, train acc:0.24666666666666667, test acc:0.2216 ===
# train loss:2.1671559124337723
# train loss:2.112469926027484
# train loss:2.114276949283816
# === epoch:121, train acc:0.24666666666666667, test acc:0.2228 ===
# train loss:2.109240287475935
# train loss:2.131235076658355
# train loss:2.1008616926244525
# === epoch:122, train acc:0.25, test acc:0.2227 ===
# train loss:2.095474115262112
# train loss:2.1457329769710167
# train loss:2.1202771570135623
# === epoch:123, train acc:0.25333333333333335, test acc:0.2242 ===
# train loss:2.0671474050594174
# train loss:2.1200203507783626
# train loss:2.087663393265345
# === epoch:124, train acc:0.25666666666666665, test acc:0.2246 ===
# train loss:2.0809921979824018
# train loss:2.1431412365548344
# train loss:2.09931141667001
# === epoch:125, train acc:0.25333333333333335, test acc:0.2251 ===
# train loss:2.09478762613965
# train loss:2.1227493987293253
# train loss:2.1006927314379977
# === epoch:126, train acc:0.25333333333333335, test acc:0.2253 ===
# train loss:2.1105406118287195
# train loss:2.117642871013258
# train loss:2.0853971344008584
# === epoch:127, train acc:0.25666666666666665, test acc:0.2261 ===
# train loss:2.116083467325425
# train loss:2.06137442878665
# train loss:2.1031004881325144
# === epoch:128, train acc:0.26, test acc:0.2271 ===
# train loss:2.0846210613274443
# train loss:2.148757461074189
# train loss:2.099245310580341
# === epoch:129, train acc:0.2633333333333333, test acc:0.2282 ===
# train loss:2.053162355203108
# train loss:2.091602301115789
# train loss:2.0253151861506122
# === epoch:130, train acc:0.2633333333333333, test acc:0.2271 ===
# train loss:2.1100241746214574
# train loss:2.0400769816415623
# train loss:2.046585282580885
# === epoch:131, train acc:0.2633333333333333, test acc:0.228 ===
# train loss:2.100460255340281
# train loss:2.139671625720357
# train loss:2.108077329273573
# === epoch:132, train acc:0.26666666666666666, test acc:0.2292 ===
# train loss:2.122576803990906
# train loss:2.049721850074067
# train loss:2.159354918545651
# === epoch:133, train acc:0.28, test acc:0.232 ===
# train loss:2.118643144176936
# train loss:2.097434470556853
# train loss:2.1131067071835927
# === epoch:134, train acc:0.2833333333333333, test acc:0.2357 ===
# train loss:2.1391410126267587
# train loss:2.119828270627019
# train loss:2.1270642796646273
# === epoch:135, train acc:0.28, test acc:0.2375 ===
# train loss:2.131728942484015
# train loss:2.0654243634438765
# train loss:2.0959632790632092
# === epoch:136, train acc:0.2866666666666667, test acc:0.2396 ===
# train loss:2.0960689733645013
# train loss:2.057444026301402
# train loss:2.088220984575075
# === epoch:137, train acc:0.29, test acc:0.2391 ===
# train loss:2.0361626328724314
# train loss:2.0051169341667587
# train loss:2.0601457853092437
# === epoch:138, train acc:0.2866666666666667, test acc:0.2378 ===
# train loss:2.0703206525054263
# train loss:2.0604050607513664
# train loss:2.076289184302631
# === epoch:139, train acc:0.29333333333333333, test acc:0.2409 ===
# train loss:2.0588676551134664
# train loss:2.0445013611319873
# train loss:2.0474821572876736
# === epoch:140, train acc:0.29, test acc:0.2396 ===
# train loss:2.1216197763798683
# train loss:2.0477205391261477
# train loss:2.088921656853915
# === epoch:141, train acc:0.29333333333333333, test acc:0.2429 ===
# train loss:2.0636170310024387
# train loss:2.087533037783625
# train loss:2.026977005533009
# === epoch:142, train acc:0.29333333333333333, test acc:0.2426 ===
# train loss:2.0452841881680404
# train loss:2.1196671955356305
# train loss:2.068296770064885
# === epoch:143, train acc:0.3, test acc:0.2469 ===
# train loss:2.0949978889003313
# train loss:2.1342115571532587
# train loss:2.0815383581277134
# === epoch:144, train acc:0.30666666666666664, test acc:0.2514 ===
# train loss:2.122165071836653
# train loss:2.0723331118797588
# train loss:2.097661828466357
# === epoch:145, train acc:0.31, test acc:0.2562 ===
# train loss:2.03463838136374
# train loss:1.9571590917537762
# train loss:1.9792405930989008
# === epoch:146, train acc:0.31, test acc:0.2538 ===
# train loss:2.0715625595368774
# train loss:2.0865524106183435
# train loss:1.974183538786508
# === epoch:147, train acc:0.30666666666666664, test acc:0.2534 ===
# train loss:2.0050777458616693
# train loss:2.0665761100491387
# train loss:1.9754917044057436
# === epoch:148, train acc:0.30666666666666664, test acc:0.2532 ===
# train loss:2.0180431914510284
# train loss:2.0037647754399552
# train loss:2.0203932652485066
# === epoch:149, train acc:0.30666666666666664, test acc:0.2539 ===
# train loss:1.9736504914912611
# train loss:2.0222370272236625
# train loss:1.944559131944433
# === epoch:150, train acc:0.30333333333333334, test acc:0.2528 ===
# train loss:1.9617977142224123
# train loss:1.996892977119253
# train loss:2.10102800982553
# === epoch:151, train acc:0.30333333333333334, test acc:0.2541 ===
# train loss:1.9320228371904649
# train loss:2.049998766004369
# train loss:1.9756411085978576
# === epoch:152, train acc:0.3, test acc:0.2528 ===
# train loss:2.019346560722271
# train loss:1.9965412422744555
# train loss:1.9538444927623027
# === epoch:153, train acc:0.30333333333333334, test acc:0.2549 ===
# train loss:2.089099727713235
# train loss:1.9986260755826402
# train loss:2.090121859669659
# === epoch:154, train acc:0.32, test acc:0.2607 ===
# train loss:2.0676818340929306
# train loss:1.970063344111567
# train loss:2.033559252195466
# === epoch:155, train acc:0.3233333333333333, test acc:0.2662 ===
# train loss:1.960801550954178
# train loss:2.097474703025718
# train loss:2.087805905305063
# === epoch:156, train acc:0.3466666666666667, test acc:0.2719 ===
# train loss:2.0249437792678986
# train loss:1.956319443089481
# train loss:2.002314930480733
# === epoch:157, train acc:0.35333333333333333, test acc:0.2744 ===
# train loss:1.92571870558422
# train loss:2.0391191552442796
# train loss:2.0759072105692753
# === epoch:158, train acc:0.36666666666666664, test acc:0.2791 ===
# train loss:2.0306278018176673
# train loss:1.9797276541789706
# train loss:1.918465859943065
# === epoch:159, train acc:0.37666666666666665, test acc:0.2823 ===
# train loss:2.0082271273210686
# train loss:2.0242619029824884
# train loss:2.024859892073115
# === epoch:160, train acc:0.38333333333333336, test acc:0.2832 ===
# train loss:1.9821016370355746
# train loss:1.9870264682429386
# train loss:1.9160972664651843
# === epoch:161, train acc:0.37, test acc:0.279 ===
# train loss:2.03509601711343
# train loss:1.979028753074523
# train loss:1.9670806745268063
# === epoch:162, train acc:0.38, test acc:0.2808 ===
# train loss:1.9655820298853686
# train loss:1.9751788323370523
# train loss:1.9752897358946018
# === epoch:163, train acc:0.38, test acc:0.2789 ===
# train loss:2.0111303349842915
# train loss:2.0720920380947465
# train loss:1.9886002253916362
# === epoch:164, train acc:0.38, test acc:0.2806 ===
# train loss:2.071586790802604
# train loss:1.951872974120195
# train loss:1.9849367185343385
# === epoch:165, train acc:0.38333333333333336, test acc:0.2848 ===
# train loss:2.053431138096982
# train loss:2.000379056714882
# train loss:1.9991560242197004
# === epoch:166, train acc:0.38, test acc:0.2885 ===
# train loss:1.9760895038281703
# train loss:2.0268714468242974
# train loss:1.9363699978601396
# === epoch:167, train acc:0.38666666666666666, test acc:0.2892 ===
# train loss:1.9585725274939474
# train loss:1.9499834434431451
# train loss:2.016889315051992
# === epoch:168, train acc:0.38666666666666666, test acc:0.2906 ===
# train loss:1.8235349774938547
# train loss:1.9783033390707225
# train loss:1.9278797236995242
# === epoch:169, train acc:0.38666666666666666, test acc:0.289 ===
# train loss:1.9421183231079604
# train loss:1.9316412791002397
# train loss:2.0528673651655795
# === epoch:170, train acc:0.39, test acc:0.2903 ===
# train loss:1.956604423556445
# train loss:1.984158193022305
# train loss:2.028994885870723
# === epoch:171, train acc:0.3933333333333333, test acc:0.2927 ===
# train loss:1.7659102422456001
# train loss:2.0053479326600527
# train loss:1.91980375960544
# === epoch:172, train acc:0.3933333333333333, test acc:0.294 ===
# train loss:1.9718726869184833
# train loss:1.8886503311913663
# train loss:1.9703044552987143
# === epoch:173, train acc:0.39666666666666667, test acc:0.2972 ===
# train loss:1.9073139776312558
# train loss:1.9272096127382325
# train loss:1.8943137873361635
# === epoch:174, train acc:0.39666666666666667, test acc:0.2942 ===
# train loss:1.8930681034631172
# train loss:1.9934120156494533
# train loss:2.051573308733701
# === epoch:175, train acc:0.3933333333333333, test acc:0.2969 ===
# train loss:1.979188712181839
# train loss:1.9156229440973638
# train loss:1.902238032336928
# === epoch:176, train acc:0.4, test acc:0.2977 ===
# train loss:2.0330409014018436
# train loss:1.9002514725817252
# train loss:1.9525806291358707
# === epoch:177, train acc:0.39666666666666667, test acc:0.298 ===
# train loss:2.0988306665308984
# train loss:1.980196283459079
# train loss:1.941446778416007
# === epoch:178, train acc:0.41333333333333333, test acc:0.3071 ===
# train loss:1.8609929265548728
# train loss:1.9090664850803367
# train loss:1.9134711403811666
# === epoch:179, train acc:0.41333333333333333, test acc:0.3045 ===
# train loss:1.9358315635929697
# train loss:1.9300321356963346
# train loss:1.891405049062319
# === epoch:180, train acc:0.41333333333333333, test acc:0.3077 ===
# train loss:2.0087585001627475
# train loss:1.900828362603155
# train loss:1.983550604606282
# === epoch:181, train acc:0.42333333333333334, test acc:0.3136 ===
# train loss:2.0190465404013698
# train loss:1.9204632871061562
# train loss:1.8984528878875653
# === epoch:182, train acc:0.4266666666666667, test acc:0.3161 ===
# train loss:1.9148475215899594
# train loss:1.9224724734707248
# train loss:1.833298284896618
# === epoch:183, train acc:0.4266666666666667, test acc:0.3183 ===
# train loss:1.9525312896288396
# train loss:1.9286800242216935
# train loss:1.9994355435792661
# === epoch:184, train acc:0.43333333333333335, test acc:0.3294 ===
# train loss:1.9383167902472203
# train loss:1.957594177526838
# train loss:1.892294112912678
# === epoch:185, train acc:0.43, test acc:0.3333 ===
# train loss:1.9114084993024065
# train loss:1.909636008640028
# train loss:1.829997178110626
# === epoch:186, train acc:0.43333333333333335, test acc:0.3315 ===
# train loss:1.928181559853111
# train loss:1.9576124955208687
# train loss:1.983050381807574
# === epoch:187, train acc:0.43333333333333335, test acc:0.3356 ===
# train loss:1.8885852078775045
# train loss:1.9291348134777766
# train loss:2.0248164784030576
# === epoch:188, train acc:0.43333333333333335, test acc:0.3437 ===
# train loss:1.9855935797297661
# train loss:1.9274314494331828
# train loss:1.9465495863620819
# === epoch:189, train acc:0.43333333333333335, test acc:0.3467 ===
# train loss:1.9151199104151748
# train loss:1.9184573064310255
# train loss:1.905118628575055
# === epoch:190, train acc:0.43666666666666665, test acc:0.3497 ===
# train loss:1.9214855088024247
# train loss:1.9013415014855923
# train loss:1.985654776227146
# === epoch:191, train acc:0.44, test acc:0.3507 ===
# train loss:1.7991429712419864
# train loss:1.8341596934567883
# train loss:1.9805452495830342
# === epoch:192, train acc:0.45, test acc:0.3524 ===
# train loss:1.8567843630026968
# train loss:1.8835827283244193
# train loss:1.7969278963241073
# === epoch:193, train acc:0.4533333333333333, test acc:0.3537 ===
# train loss:1.9129621877206986
# train loss:1.8159471071177185
# train loss:1.9696666422501314
# === epoch:194, train acc:0.4533333333333333, test acc:0.3558 ===
# train loss:1.8687755737451324
# train loss:1.9914424307087955
# train loss:1.8892088629552999
# === epoch:195, train acc:0.46, test acc:0.3597 ===
# train loss:1.8469728440996942
# train loss:1.7945970072493338
# train loss:1.8153800942464722
# === epoch:196, train acc:0.45, test acc:0.3581 ===
# train loss:1.8202592621586595
# train loss:1.871711685373115
# train loss:1.8702122106626213
# === epoch:197, train acc:0.45, test acc:0.3556 ===
# train loss:1.8269713877291245
# train loss:1.8256238459412406
# train loss:1.9405307347676464
# === epoch:198, train acc:0.46, test acc:0.3601 ===
# train loss:1.946767418293813
# train loss:1.9895822256229665
# train loss:1.9739945739312987
# === epoch:199, train acc:0.4633333333333333, test acc:0.3703 ===
# train loss:1.8631336369342215
# train loss:1.9026756871504455
# train loss:1.8337133671487853
# === epoch:200, train acc:0.47333333333333333, test acc:0.3731 ===
# train loss:1.911808504202698
# train loss:1.866644882586383
# train loss:1.8847289261335909
# === epoch:201, train acc:0.47, test acc:0.3735 ===
# train loss:1.9049620767308495
# train loss:1.8793708806604417
# train loss:1.9601651126201205
# === epoch:202, train acc:0.4766666666666667, test acc:0.3759 ===
# train loss:1.9114890078667885
# train loss:1.881586232487978
# train loss:1.9141440303619075
# === epoch:203, train acc:0.47333333333333333, test acc:0.3791 ===
# train loss:1.9099781917359346
# train loss:1.8437459341365434
# train loss:1.9269468183939213
# === epoch:204, train acc:0.47333333333333333, test acc:0.3854 ===
# train loss:1.8711539862196531
# train loss:1.9732238423988775
# train loss:1.8018101751648077
# === epoch:205, train acc:0.4766666666666667, test acc:0.3859 ===
# train loss:1.90108345213785
# train loss:1.902002188257293
# train loss:1.8206744289650425
# === epoch:206, train acc:0.48, test acc:0.392 ===
# train loss:1.910964062306636
# train loss:1.9372590681079251
# train loss:1.9466158343242617
# === epoch:207, train acc:0.4866666666666667, test acc:0.3955 ===
# train loss:1.893990451734362
# train loss:1.7644834738130317
# train loss:1.8492632048744324
# === epoch:208, train acc:0.48333333333333334, test acc:0.3975 ===
# train loss:1.802452624162018
# train loss:1.932095640156214
# train loss:1.7803912794982433
# === epoch:209, train acc:0.48333333333333334, test acc:0.3959 ===
# train loss:1.8430359840125425
# train loss:1.6417609199301477
# train loss:1.9159634198372286
# === epoch:210, train acc:0.4866666666666667, test acc:0.3992 ===
# train loss:1.7466044285195073
# train loss:1.8443897606874453
# train loss:1.8974831557002174
# === epoch:211, train acc:0.4866666666666667, test acc:0.3996 ===
# train loss:1.8258294132159891
# train loss:1.9295612554992374
# train loss:1.7615642797426083
# === epoch:212, train acc:0.4866666666666667, test acc:0.4013 ===
# train loss:1.8514925744016864
# train loss:1.7977079598799424
# train loss:1.9334526505089904
# === epoch:213, train acc:0.49333333333333335, test acc:0.4047 ===
# train loss:1.8312861280561665
# train loss:1.8253875176572132
# train loss:1.7647898227102314
# === epoch:214, train acc:0.49, test acc:0.4028 ===
# train loss:1.76691920880436
# train loss:1.859569166355073
# train loss:1.8130519426764968
# === epoch:215, train acc:0.49333333333333335, test acc:0.4043 ===
# train loss:1.8774321804553613
# train loss:1.7555350224896065
# train loss:1.644305749370302
# === epoch:216, train acc:0.4866666666666667, test acc:0.4017 ===
# train loss:1.883034434552352
# train loss:1.7324071427261536
# train loss:1.7892016043173598
# === epoch:217, train acc:0.49, test acc:0.4048 ===
# train loss:1.777263662588704
# train loss:1.8076391688818658
# train loss:1.8419855948753052
# === epoch:218, train acc:0.49333333333333335, test acc:0.4068 ===
# train loss:1.905245824368813
# train loss:1.8579880432409766
# train loss:1.8155814869680942
# === epoch:219, train acc:0.49666666666666665, test acc:0.4073 ===
# train loss:1.7108521808015769
# train loss:1.7012609076833671
# train loss:1.7407252927636672
# === epoch:220, train acc:0.49, test acc:0.4051 ===
# train loss:1.7600510415418409
# train loss:1.8108032700861645
# train loss:1.8494288307657683
# === epoch:221, train acc:0.48333333333333334, test acc:0.4103 ===
# train loss:1.7992498007066067
# train loss:1.672676293449273
# train loss:1.8005420375155063
# === epoch:222, train acc:0.4866666666666667, test acc:0.4117 ===
# train loss:1.8638025286235174
# train loss:1.809787667993309
# train loss:1.8557233693355313
# === epoch:223, train acc:0.49333333333333335, test acc:0.4165 ===
# train loss:1.7319433516536527
# train loss:1.8052586219025628
# train loss:1.9005282612429806
# === epoch:224, train acc:0.49333333333333335, test acc:0.4151 ===
# train loss:1.7451530820303605
# train loss:1.6641297721389428
# train loss:1.6815470638924543
# === epoch:225, train acc:0.49666666666666665, test acc:0.4151 ===
# train loss:1.8886945569746283
# train loss:1.8017148298338839
# train loss:1.8137155414421344
# === epoch:226, train acc:0.5, test acc:0.4198 ===
# train loss:1.7323764745585108
# train loss:1.795214530270886
# train loss:1.732794914258946
# === epoch:227, train acc:0.5, test acc:0.4227 ===
# train loss:1.783352985774467
# train loss:1.718556041898578
# train loss:1.7684437716832841
# === epoch:228, train acc:0.49666666666666665, test acc:0.4243 ===
# train loss:1.7890795094495449
# train loss:1.7638762129971104
# train loss:1.7321914656142658
# === epoch:229, train acc:0.49666666666666665, test acc:0.4272 ===
# train loss:1.7713740592066713
# train loss:1.7331405029236708
# train loss:1.7692656978078458
# === epoch:230, train acc:0.49666666666666665, test acc:0.4281 ===
# train loss:1.768618759090133
# train loss:1.6698572310642532
# train loss:1.8456319389452613
# === epoch:231, train acc:0.49666666666666665, test acc:0.4307 ===
# train loss:1.81298415547803
# train loss:1.798846916505901
# train loss:1.7328288837843748
# === epoch:232, train acc:0.5033333333333333, test acc:0.4323 ===
# train loss:1.6590517458644047
# train loss:1.8000135231128158
# train loss:1.7803562773397812
# === epoch:233, train acc:0.5, test acc:0.4345 ===
# train loss:1.7807298243378755
# train loss:1.7028794340194542
# train loss:1.6873555752833567
# === epoch:234, train acc:0.5066666666666667, test acc:0.4351 ===
# train loss:1.7235776256027566
# train loss:1.736027453477602
# train loss:1.7581197629708603
# === epoch:235, train acc:0.5133333333333333, test acc:0.4357 ===
# train loss:1.6823044394549345
# train loss:1.6674300424539026
# train loss:1.7699936905992792
# === epoch:236, train acc:0.5133333333333333, test acc:0.4362 ===
# train loss:1.7696117702436012
# train loss:1.5251767844915929
# train loss:1.6313547540497038
# === epoch:237, train acc:0.51, test acc:0.4359 ===
# train loss:1.7287062192966018
# train loss:1.7784400058428897
# train loss:1.685332663065354
# === epoch:238, train acc:0.5133333333333333, test acc:0.4408 ===
# train loss:1.6990743941448454
# train loss:1.6385540915349472
# train loss:1.7571613743973973
# === epoch:239, train acc:0.5133333333333333, test acc:0.4398 ===
# train loss:1.7450319978396933
# train loss:1.7254980879794533
# train loss:1.6445423178521907
# === epoch:240, train acc:0.5133333333333333, test acc:0.4424 ===
# train loss:1.6813854732051536
# train loss:1.713957838930478
# train loss:1.8087269241707986
# === epoch:241, train acc:0.51, test acc:0.4441 ===
# train loss:1.8068580467421764
# train loss:1.7011465944340527
# train loss:1.6356150155872613
# === epoch:242, train acc:0.5066666666666667, test acc:0.4442 ===
# train loss:1.663135697525323
# train loss:1.8108690434298576
# train loss:1.6946733159198957
# === epoch:243, train acc:0.5066666666666667, test acc:0.4425 ===
# train loss:1.6256837052039512
# train loss:1.7601007751441555
# train loss:1.8905563871969262
# === epoch:244, train acc:0.51, test acc:0.4418 ===
# train loss:1.584377859011243
# train loss:1.6515305334321635
# train loss:1.7116567606530972
# === epoch:245, train acc:0.51, test acc:0.4403 ===
# train loss:1.612953461917615
# train loss:1.6170593916295775
# train loss:1.643400628090063
# === epoch:246, train acc:0.5066666666666667, test acc:0.4416 ===
# train loss:1.70139687549722
# train loss:1.6958672940823
# train loss:1.7365376101277792
# === epoch:247, train acc:0.5033333333333333, test acc:0.4418 ===
# train loss:1.6021044271462817
# train loss:1.6158862778693555
# train loss:1.6323389352496143
# === epoch:248, train acc:0.5066666666666667, test acc:0.4436 ===
# train loss:1.5630604740870675
# train loss:1.69719934937953
# train loss:1.656323918618295
# === epoch:249, train acc:0.5066666666666667, test acc:0.4433 ===
# train loss:1.738146851295692
# train loss:1.6840318139662565
# train loss:1.6331344267244723
# === epoch:250, train acc:0.51, test acc:0.4467 ===
# train loss:1.6307991201696748
# train loss:1.6413187175570452
# train loss:1.7290518882313213
# === epoch:251, train acc:0.5066666666666667, test acc:0.4484 ===
# train loss:1.6142605007736868
# train loss:1.6066811672617214
# train loss:1.8328833928783737
# === epoch:252, train acc:0.51, test acc:0.4514 ===
# train loss:1.5491644480239928
# train loss:1.7018678732147494
# train loss:1.6913284291874553
# === epoch:253, train acc:0.5066666666666667, test acc:0.4493 ===
# train loss:1.742383355429024
# train loss:1.7078475618688072
# train loss:1.6699909482661242
# === epoch:254, train acc:0.51, test acc:0.4514 ===
# train loss:1.7861881780879258
# train loss:1.6744262370338598
# train loss:1.6655290217643135
# === epoch:255, train acc:0.51, test acc:0.4544 ===
# train loss:1.5070046331377476
# train loss:1.729911340379508
# train loss:1.6081576822198718
# === epoch:256, train acc:0.52, test acc:0.4538 ===
# train loss:1.6866550818569317
# train loss:1.6459006568224581
# train loss:1.5822702620031586
# === epoch:257, train acc:0.5233333333333333, test acc:0.4546 ===
# train loss:1.5432857207512922
# train loss:1.607321719303409
# train loss:1.5958531158991673
# === epoch:258, train acc:0.52, test acc:0.4557 ===
# train loss:1.6392052908641992
# train loss:1.6873805927304601
# train loss:1.6231812946715158
# === epoch:259, train acc:0.52, test acc:0.4582 ===
# train loss:1.6048667032412167
# train loss:1.5644917211903089
# train loss:1.6947961964145524
# === epoch:260, train acc:0.5233333333333333, test acc:0.4589 ===
# train loss:1.5067684524895455
# train loss:1.513827672012083
# train loss:1.5562521920774077
# === epoch:261, train acc:0.52, test acc:0.4568 ===
# train loss:1.5782509453461548
# train loss:1.6437853154108588
# train loss:1.5352486453393916
# === epoch:262, train acc:0.5233333333333333, test acc:0.4578 ===
# train loss:1.6652501757593146
# train loss:1.6437252535516635
# train loss:1.5107937129106097
# === epoch:263, train acc:0.5266666666666666, test acc:0.4598 ===
# train loss:1.6881968659043338
# train loss:1.6792133160772638
# train loss:1.596801613620724
# === epoch:264, train acc:0.53, test acc:0.4605 ===
# train loss:1.5932289786240907
# train loss:1.534588442298796
# train loss:1.6979544812012168
# === epoch:265, train acc:0.5333333333333333, test acc:0.4651 ===
# train loss:1.5719200058128846
# train loss:1.5592937051612543
# train loss:1.6705788556749908
# === epoch:266, train acc:0.5366666666666666, test acc:0.464 ===
# train loss:1.6086662751138974
# train loss:1.5342528927465375
# train loss:1.6004464504112252
# === epoch:267, train acc:0.5366666666666666, test acc:0.4657 ===
# train loss:1.7015236070210142
# train loss:1.6207417546999268
# train loss:1.5347740803839756
# === epoch:268, train acc:0.5366666666666666, test acc:0.4658 ===
# train loss:1.5191832257371976
# train loss:1.5511352115691048
# train loss:1.8186328912074325
# === epoch:269, train acc:0.5366666666666666, test acc:0.4661 ===
# train loss:1.6387468868844133
# train loss:1.5921241050948507
# train loss:1.6913982743429978
# === epoch:270, train acc:0.54, test acc:0.4684 ===
# train loss:1.5316987735128067
# train loss:1.5045690002141585
# train loss:1.5806673284542088
# === epoch:271, train acc:0.5466666666666666, test acc:0.4711 ===
# train loss:1.5158590938435372
# train loss:1.5335097597720175
# train loss:1.4476820082078934
# === epoch:272, train acc:0.54, test acc:0.4699 ===
# train loss:1.685011368428067
# train loss:1.6131796292037879
# train loss:1.6895710636570036
# === epoch:273, train acc:0.5433333333333333, test acc:0.4693 ===
# train loss:1.5422344284222564
# train loss:1.573274171319784
# train loss:1.695464253067846
# === epoch:274, train acc:0.54, test acc:0.4712 ===
# train loss:1.6181605918327282
# train loss:1.6786544626174484
# train loss:1.6655859106632382
# === epoch:275, train acc:0.55, test acc:0.4718 ===
# train loss:1.575309987496284
# train loss:1.564773900906209
# train loss:1.533787658498894
# === epoch:276, train acc:0.5466666666666666, test acc:0.4725 ===
# train loss:1.6680078293518747
# train loss:1.499310069002801
# train loss:1.5569442534992874
# === epoch:277, train acc:0.5466666666666666, test acc:0.4752 ===
# train loss:1.433769842339623
# train loss:1.495251331488922
# train loss:1.4173253751440518
# === epoch:278, train acc:0.5466666666666666, test acc:0.4749 ===
# train loss:1.6105096921559032
# train loss:1.472120094315307
# train loss:1.4883970150159436
# === epoch:279, train acc:0.5466666666666666, test acc:0.4753 ===
# train loss:1.5862395789107209
# train loss:1.7027148948100967
# train loss:1.6170635705387448
# === epoch:280, train acc:0.55, test acc:0.4765 ===
# train loss:1.5342390183791434
# train loss:1.475650723297607
# train loss:1.555904341712842
# === epoch:281, train acc:0.55, test acc:0.4761 ===
# train loss:1.5668193751289539
# train loss:1.5898925120541636
# train loss:1.5372590336178162
# === epoch:282, train acc:0.5566666666666666, test acc:0.4757 ===
# train loss:1.5242045863284912
# train loss:1.5084370205428579
# train loss:1.509411453781515
# === epoch:283, train acc:0.56, test acc:0.479 ===
# train loss:1.6153251491104452
# train loss:1.5038629939887926
# train loss:1.4700946224795746
# === epoch:284, train acc:0.5633333333333334, test acc:0.4829 ===
# train loss:1.4677340621066872
# train loss:1.435659078314319
# train loss:1.5314828113879864
# === epoch:285, train acc:0.5633333333333334, test acc:0.4818 ===
# train loss:1.5674619376793517
# train loss:1.5583531730816813
# train loss:1.4750960046410384
# === epoch:286, train acc:0.57, test acc:0.4828 ===
# train loss:1.3716737645903943
# train loss:1.5372633706469796
# train loss:1.4463354709265224
# === epoch:287, train acc:0.57, test acc:0.4841 ===
# train loss:1.4477241971558927
# train loss:1.4744413003909096
# train loss:1.6441262660947873
# === epoch:288, train acc:0.5733333333333334, test acc:0.4854 ===
# train loss:1.3341878288117188
# train loss:1.5143882973334508
# train loss:1.4841054444923243
# === epoch:289, train acc:0.57, test acc:0.4844 ===
# train loss:1.4253720600733342
# train loss:1.6315001925440282
# train loss:1.5584584940252468
# === epoch:290, train acc:0.5766666666666667, test acc:0.4876 ===
# train loss:1.5452794604936089
# train loss:1.5118799470883182
# train loss:1.4865026414774514
# === epoch:291, train acc:0.5733333333333334, test acc:0.4896 ===
# train loss:1.529105219667702
# train loss:1.4030239685558141
# train loss:1.5639457438541466
# === epoch:292, train acc:0.58, test acc:0.4918 ===
# train loss:1.3534184331812513
# train loss:1.5558763341227555
# train loss:1.5524523794296403
# === epoch:293, train acc:0.5866666666666667, test acc:0.494 ===
# train loss:1.4160827421776119
# train loss:1.6111287392476603
# train loss:1.528288911242346
# === epoch:294, train acc:0.59, test acc:0.4982 ===
# train loss:1.4604728908901898
# train loss:1.502491312366621
# train loss:1.3636236541634477
# === epoch:295, train acc:0.5866666666666667, test acc:0.4968 ===
# train loss:1.5413494696056065
# train loss:1.4778135105495156
# train loss:1.4506981273229775
# === epoch:296, train acc:0.5966666666666667, test acc:0.5006 ===
# train loss:1.4059249526149593
# train loss:1.3565536856437008
# train loss:1.3699156095173035
# === epoch:297, train acc:0.5933333333333334, test acc:0.5011 ===
# train loss:1.4083025622368677
# train loss:1.5629182346955723
# train loss:1.2467130675097338
# === epoch:298, train acc:0.5866666666666667, test acc:0.5015 ===
# train loss:1.4274025092395959
# train loss:1.4939298518340594
# train loss:1.3784146509395243
# === epoch:299, train acc:0.5933333333333334, test acc:0.5025 ===
# train loss:1.4440043046336948
# train loss:1.5029787425419583
# train loss:1.393662244857889
# === epoch:300, train acc:0.59, test acc:0.5017 ===
# train loss:1.39824807763329
# train loss:1.4613293693722988
# train loss:1.5062991016947125
# === epoch:301, train acc:0.5866666666666667, test acc:0.5045 ===
# train loss:1.437910588139034
# train loss:1.7356771854874666
# =============== Final Test Accuracy ===============
# test acc:0.506

# %%
markers = {'train': 'o', 'test': 's'}
x = np.arange(len(train_acc_list))
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## For the best Hyperparamiter

# %%
from common.util import shuffle_dataset
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)
x_train, t_train = shuffle_dataset(x_train, t_train)
validation_rate = 0.20
validation_num = int(x_train.shape[0] * validation_rate)
x_val = x_train[:validation_num]
t_val = t_train[:validation_num]
x_train = x_train[validation_num:]
t_train = t_train[validation_num:]

# %%
import sys, os
sys.path.append("../DLFS_book/")  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.util import shuffle_dataset
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 결과를 빠르게 얻기 위해 훈련 데이터를 줄임
x_train = x_train[:500]
t_train = t_train[:500]

# 20%를 검증 데이터로 분할
validation_rate = 0.20
validation_num = int(x_train.shape[0] * validation_rate)
x_train, t_train = shuffle_dataset(x_train, t_train)
x_val = x_train[:validation_num]
t_val = t_train[:validation_num]
x_train = x_train[validation_num:]
t_train = t_train[validation_num:]

# %%
def __train(lr, weight_decay, epocs=50): #get these as input
    network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                            output_size=10, weight_decay_lambda=weight_decay)
    trainer = Trainer(network, x_train, t_train, x_val, t_val,
                      epochs=epocs, mini_batch_size=100,
                      optimizer='sgd', optimizer_param={'lr': lr}, verbose=False)
    trainer.train()

    return trainer.test_acc_list, trainer.train_acc_list

# %%
# 하이퍼파라미터 무작위 탐색======================================
optimization_trial = 100
results_val = {}
results_train = {}
for _ in range(optimization_trial): #100번 시행!
    # 탐색한 하이퍼파라미터의 범위 지정===============
    weight_decay = 10 ** np.random.uniform(-8, -4)
    lr = 10 ** np.random.uniform(-6, -2)
    # ================================================

    val_acc_list, train_acc_list = __train(lr, weight_decay)
    print("val acc:" + str(val_acc_list[-1]) + " | lr:" + str(lr) + ", weight decay:" + str(weight_decay))
    key = "lr:" + str(lr) + ", weight decay:" + str(weight_decay)
    results_val[key] = val_acc_list # put accuracy in dictionary
    results_train[key] = train_acc_list
# Out:
# val acc:0.75 | lr:0.008854510576153187, weight decay:2.6339999279483582e-05
# val acc:0.12 | lr:1.7515947789163874e-06, weight decay:1.0738341600390685e-07
# val acc:0.78 | lr:0.007693539643715686, weight decay:1.7436099257792852e-05
# val acc:0.13 | lr:7.235147677986918e-06, weight decay:1.1915696807459408e-05
# val acc:0.1 | lr:1.0907424523394186e-06, weight decay:8.605905636181613e-07
# val acc:0.11 | lr:0.00018517239248786908, weight decay:2.2317081953281837e-06
# val acc:0.16 | lr:8.213063580356572e-06, weight decay:1.4593085864431215e-08
# val acc:0.19 | lr:0.0009795730797904011, weight decay:7.186127953445819e-07
# val acc:0.23 | lr:0.00129709028645021, weight decay:6.085304155904198e-08
# val acc:0.09 | lr:1.086132897652451e-05, weight decay:2.1446621102754717e-08
# val acc:0.08 | lr:3.488829838107609e-05, weight decay:3.076540586933463e-07
# val acc:0.15 | lr:2.91393355220201e-06, weight decay:3.27724961792197e-08
# val acc:0.15 | lr:0.0005584539312368874, weight decay:9.320228096833137e-05
# val acc:0.07 | lr:1.2833532636530778e-05, weight decay:1.3532744848338588e-05
# val acc:0.13 | lr:0.0003132621078516997, weight decay:2.855019362768989e-07
# val acc:0.74 | lr:0.008229728288811272, weight decay:1.024100009844486e-08
# val acc:0.2 | lr:0.0005779601721212384, weight decay:6.382936330750928e-06
# val acc:0.23 | lr:1.1524120841781643e-05, weight decay:5.288191176926944e-06
# val acc:0.11 | lr:0.00012914196779542913, weight decay:3.0444676655746055e-05
# val acc:0.12 | lr:4.335090053043866e-06, weight decay:1.3222664328010252e-05
# val acc:0.14 | lr:0.0007632471620239139, weight decay:2.526041643968577e-05
# val acc:0.24 | lr:0.0004019534430761311, weight decay:1.0274719006473794e-05
# val acc:0.47 | lr:0.003413640133816114, weight decay:1.4291426217758487e-05
# val acc:0.06 | lr:5.595050346322648e-06, weight decay:3.974069192024628e-06
# val acc:0.32 | lr:0.0013689848736199892, weight decay:6.830695326377242e-07
# val acc:0.07 | lr:0.00042610127383042515, weight decay:2.2119634798209227e-05
# val acc:0.15 | lr:0.0002953071073680859, weight decay:1.286229320299952e-08
# val acc:0.77 | lr:0.007157303286195693, weight decay:1.652652258767299e-05
# val acc:0.05 | lr:3.3557753954836854e-05, weight decay:1.0851671104756415e-06
# val acc:0.08 | lr:4.825241267405587e-06, weight decay:7.130007356820585e-07
# val acc:0.09 | lr:2.1628554358061876e-06, weight decay:9.122232794401486e-08
# val acc:0.12 | lr:5.200301995085734e-05, weight decay:1.38584117750528e-08
# val acc:0.16 | lr:3.176700447548376e-06, weight decay:3.3893862831049426e-07
# val acc:0.08 | lr:0.00013548555311008626, weight decay:2.320637027657725e-05
# val acc:0.11 | lr:1.4258183996127944e-05, weight decay:5.061226207281199e-07
# val acc:0.57 | lr:0.0044712832319914655, weight decay:1.475324239817123e-07
# val acc:0.12 | lr:0.00043925957243426384, weight decay:5.8158413389023796e-08
# val acc:0.08 | lr:0.00045237654846163846, weight decay:9.547080531383972e-07
# val acc:0.17 | lr:0.0001259531335118408, weight decay:8.025428225884547e-05
# val acc:0.08 | lr:1.145492553641456e-05, weight decay:5.978370835255206e-06
# val acc:0.09 | lr:2.19166393644726e-06, weight decay:1.5445946702969506e-07
# val acc:0.33 | lr:0.002628489800841222, weight decay:3.405300865721769e-06
# val acc:0.1 | lr:4.6531143591348295e-06, weight decay:2.640648169132764e-07
# val acc:0.84 | lr:0.009881636091091883, weight decay:1.2470388875569128e-08
# val acc:0.08 | lr:0.00020419860407204775, weight decay:3.255600543644453e-07
# val acc:0.06 | lr:5.902373982089275e-06, weight decay:7.511666037560524e-08
# val acc:0.18 | lr:0.0006452550690241696, weight decay:1.8096589445844635e-06
# val acc:0.34 | lr:0.0034089533101779035, weight decay:4.7077707634569214e-08
# val acc:0.11 | lr:8.817169552842462e-05, weight decay:1.3018000396493679e-06
# val acc:0.58 | lr:0.003920343057160842, weight decay:2.1515416039436014e-06
# val acc:0.03 | lr:1.0823264415091515e-05, weight decay:1.0363883728950115e-06
# val acc:0.17 | lr:0.0003899646067414142, weight decay:1.2327491770212773e-07
# val acc:0.09 | lr:0.0010953462702703676, weight decay:4.129072527750453e-05
# val acc:0.09 | lr:8.804642615434048e-06, weight decay:1.253127416304423e-07
# val acc:0.09 | lr:4.1710096824311303e-05, weight decay:2.027129124110505e-08
# val acc:0.08 | lr:1.5611700654254945e-05, weight decay:6.886812246884882e-07
# val acc:0.42 | lr:0.004232850280714657, weight decay:4.597437999560979e-06
# val acc:0.1 | lr:0.00013073119817840886, weight decay:2.0657363188822448e-08
# val acc:0.08 | lr:0.00021525553272017255, weight decay:8.922119096988112e-08
# val acc:0.16 | lr:1.0034487647765983e-05, weight decay:1.0504030944303644e-07
# val acc:0.15 | lr:1.125795369037166e-06, weight decay:2.031851711476156e-06
# val acc:0.26 | lr:0.001219220540993009, weight decay:1.6242151858553307e-06
# val acc:0.16 | lr:0.00022016429099546288, weight decay:7.694698047008694e-06
# val acc:0.11 | lr:0.00020186468734391866, weight decay:2.3320195815598637e-05
# val acc:0.17 | lr:0.0006630020123997443, weight decay:2.109581665627443e-08
# val acc:0.6 | lr:0.0053662885140693594, weight decay:3.554903314903992e-07
# val acc:0.15 | lr:2.9491008197509667e-06, weight decay:2.425591834716487e-06
# val acc:0.13 | lr:5.074365092433035e-05, weight decay:1.6463841176683955e-07
# val acc:0.15 | lr:0.00046063110549686106, weight decay:1.2621422425060946e-05
# val acc:0.08 | lr:2.5082554251863982e-06, weight decay:1.2199007718723102e-06
# val acc:0.77 | lr:0.005516077247741298, weight decay:5.816292502148856e-08
# val acc:0.07 | lr:1.5223577791796165e-05, weight decay:2.4344812092961036e-08
# val acc:0.11 | lr:8.312051499055606e-06, weight decay:3.215879592016961e-07
# val acc:0.73 | lr:0.005726429561311939, weight decay:5.2639078652882095e-06
# val acc:0.11 | lr:3.463325697248466e-05, weight decay:1.8975545074207053e-05
# val acc:0.08 | lr:2.362018498513478e-06, weight decay:2.621167417530209e-06
# val acc:0.15 | lr:1.1760161479670463e-05, weight decay:1.480868670989565e-05
# val acc:0.58 | lr:0.004781688543278573, weight decay:2.9740411484636146e-05
# val acc:0.35 | lr:0.0010098611809318907, weight decay:6.456075256926065e-07
# val acc:0.15 | lr:7.405563391062969e-06, weight decay:5.7951012546497933e-05
# val acc:0.41 | lr:0.004228292276848288, weight decay:1.5956483003755933e-07
# val acc:0.1 | lr:7.400200673041428e-06, weight decay:6.726691993766306e-06
# val acc:0.09 | lr:1.1331365995082455e-05, weight decay:2.1304946849554383e-06
# val acc:0.82 | lr:0.00881597244403596, weight decay:6.453364644660423e-07
# val acc:0.14 | lr:0.000364275439310967, weight decay:1.1436935114773484e-06
# val acc:0.36 | lr:0.0015689906787768584, weight decay:4.541921636294073e-06
# val acc:0.15 | lr:0.00015840518875771651, weight decay:4.1678060533334425e-08
# val acc:0.22 | lr:0.0009458549184372136, weight decay:1.9659861442733467e-05
# val acc:0.14 | lr:1.2838743112933648e-06, weight decay:1.0089489440295887e-05
# val acc:0.09 | lr:1.1432998551751352e-06, weight decay:1.398027043598323e-07
# val acc:0.76 | lr:0.008647703712258462, weight decay:6.309059265249977e-05
# val acc:0.1 | lr:3.645670145209723e-05, weight decay:3.50982312565999e-08
# val acc:0.29 | lr:0.0014674056626664325, weight decay:1.9864291494178123e-07
# val acc:0.11 | lr:0.0005461199901004466, weight decay:2.984392569852146e-05
# val acc:0.24 | lr:0.0013994847084896934, weight decay:5.20493369276782e-08
# val acc:0.17 | lr:0.000486594327864378, weight decay:6.428201092274889e-06
# val acc:0.42 | lr:0.001969383591988475, weight decay:1.7302870266960795e-05
# val acc:0.14 | lr:0.00023300907557434217, weight decay:5.6778301014099305e-05
# val acc:0.21 | lr:0.000466743456232493, weight decay:1.2121692529198321e-06
# val acc:0.13 | lr:0.0002229922858712141, weight decay:2.441290980757858e-08

# %%
# 그래프 그리기========================================================
print("=========== Hyper-Parameter Optimization Result ===========")
graph_draw_num = 20 #draw 20 of the best ones
col_num = 5
row_num = int(np.ceil(graph_draw_num / col_num)) #4
i = 0

for key, val_acc_list in sorted(results_val.items(), key=lambda x:x[1][-1], reverse=True):
    print("Best-" + str(i+1) + "(val acc:" + str(val_acc_list[-1]) + ") | " + key)

    plt.subplot(row_num, col_num, i+1)
    plt.title("Best-" + str(i+1))
    plt.ylim(0.0, 1.0)
    if i % 5: plt.yticks([])
    plt.xticks([])
    x = np.arange(len(val_acc_list))
    plt.plot(x, val_acc_list)
    plt.plot(x, results_train[key], "--")
    i += 1

    if i >= graph_draw_num:
        break

plt.show()
# Out:
# =========== Hyper-Parameter Optimization Result ===========
# Best-1(val acc:0.84) | lr:0.009881636091091883, weight decay:1.2470388875569128e-08
# Best-2(val acc:0.82) | lr:0.00881597244403596, weight decay:6.453364644660423e-07
# Best-3(val acc:0.78) | lr:0.007693539643715686, weight decay:1.7436099257792852e-05
# Best-4(val acc:0.77) | lr:0.007157303286195693, weight decay:1.652652258767299e-05
# Best-5(val acc:0.77) | lr:0.005516077247741298, weight decay:5.816292502148856e-08
# Best-6(val acc:0.76) | lr:0.008647703712258462, weight decay:6.309059265249977e-05
# Best-7(val acc:0.75) | lr:0.008854510576153187, weight decay:2.6339999279483582e-05
# Best-8(val acc:0.74) | lr:0.008229728288811272, weight decay:1.024100009844486e-08
# Best-9(val acc:0.73) | lr:0.005726429561311939, weight decay:5.2639078652882095e-06
# Best-10(val acc:0.6) | lr:0.0053662885140693594, weight decay:3.554903314903992e-07
# Best-11(val acc:0.58) | lr:0.003920343057160842, weight decay:2.1515416039436014e-06
# Best-12(val acc:0.58) | lr:0.004781688543278573, weight decay:2.9740411484636146e-05
# Best-13(val acc:0.57) | lr:0.0044712832319914655, weight decay:1.475324239817123e-07
# Best-14(val acc:0.47) | lr:0.003413640133816114, weight decay:1.4291426217758487e-05
# Best-15(val acc:0.42) | lr:0.004232850280714657, weight decay:4.597437999560979e-06
# Best-16(val acc:0.42) | lr:0.001969383591988475, weight decay:1.7302870266960795e-05
# Best-17(val acc:0.41) | lr:0.004228292276848288, weight decay:1.5956483003755933e-07
# Best-18(val acc:0.36) | lr:0.0015689906787768584, weight decay:4.541921636294073e-06
# Best-19(val acc:0.35) | lr:0.0010098611809318907, weight decay:6.456075256926065e-07
# Best-20(val acc:0.34) | lr:0.0034089533101779035, weight decay:4.7077707634569214e-08
